# %%
# Cell 1: Import Libraries and Install Requirements
# Install required packages
# !pip install azure-storage-blob

# Import all the tools we need
import requests
import pandas as pd
from datetime import datetime, timedelta
from bs4 import BeautifulSoup
import json
import time

# Check if imports worked
print("All libraries imported successfully!")
print(f"Current time: {datetime.now()}")
# Out:
# Requirement already satisfied: azure-storage-blob in c:\users\bjlce\anaconda3\lib\site-packages (12.26.0)
# Requirement already satisfied: azure-core>=1.30.0 in c:\users\bjlce\anaconda3\lib\site-packages (from azure-storage-blob) (1.35.0)
# Requirement already satisfied: cryptography>=2.1.4 in c:\users\bjlce\anaconda3\lib\site-packages (from azure-storage-blob) (43.0.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\bjlce\anaconda3\lib\site-packages (from azure-storage-blob) (4.14.0)
# Requirement already satisfied: isodate>=0.6.1 in c:\users\bjlce\anaconda3\lib\site-packages (from azure-storage-blob) (0.7.2)
# Requirement already satisfied: requests>=2.21.0 in c:\users\bjlce\anaconda3\lib\site-packages (from azure-core>=1.30.0->azure-storage-blob) (2.32.3)
# Requirement already satisfied: six>=1.11.0 in c:\users\bjlce\anaconda3\lib\site-packages (from azure-core>=1.30.0->azure-storage-blob) (1.16.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\bjlce\anaconda3\lib\site-packages (from cryptography>=2.1.4->azure-storage-blob) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\bjlce\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=2.1.4->azure-storage-blob) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\bjlce\anaconda3\lib\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-storage-blob) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\bjlce\anaconda3\lib\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-storage-blob) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\bjlce\anaconda3\lib\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-storage-blob) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bjlce\anaconda3\lib\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-storage-blob) (2025.4.26)
# All libraries imported successfully!
# Current time: 2025-07-30 10:44:56.712707

# %%
# Target hotels
hotels = [
    {"name": "Pendry Manhattan West", "id": "68272643"},
    {"name": "The Mercer", "id": "118588"},
    {"name": "Hotel Barriere Fouquets", "id": "88270883"},
    {"name": "Casa Cipriani", "id": "60020170"},
    {"name": "The Mark", "id": "19712"},
    {"name": "Baccarat Hotel and Residences", "id": "9759603"}
]

# Display hotels
for hotel in hotels:
    print(f"{hotel['name']} (ID: {hotel['id']})")
# Out:
# Pendry Manhattan West (ID: 68272643)
# The Mercer (ID: 118588)
# Hotel Barriere Fouquets (ID: 88270883)
# Casa Cipriani (ID: 60020170)
# The Mark (ID: 19712)
# Baccarat Hotel and Residences (ID: 9759603)

# %%
# Add this after Cell 2 to verify hotels
print(f"\nVerifying {len(hotels)} hotels:")
for i, hotel in enumerate(hotels):
    print(f"{i+1}. {hotel['name']} (ID: {hotel['id']})")
print(f"\nTotal unique hotel IDs: {len(set(h['id'] for h in hotels))}")
# Out:
# Verifying 6 hotels:
# 1. Pendry Manhattan West (ID: 68272643)
# 2. The Mercer (ID: 118588)
# 3. Hotel Barriere Fouquets (ID: 88270883)
# 4. Casa Cipriani (ID: 60020170)
# 5. The Mark (ID: 19712)
# 6. Baccarat Hotel and Residences (ID: 9759603)
#
# Total unique hotel IDs: 6

# %%
# Cell 3: Create config file (only if it doesn't exist)
import os

if os.path.exists('hip_config.txt'):
    print("✓ Config file already exists! Not overwriting.")
    print("  To add/change your token, edit 'hip_config.txt' directly.")
else:
    config_content = """# Configuration for HIP
CRAWLBASE_TOKEN=your_token_here
"""
    with open('hip_config.txt', 'w') as f:
        f.write(config_content)
    
    print("✅ Config file created!")
    print("  Now edit 'hip_config.txt' and add your Crawlbase JavaScript token")
# Out:
# ✓ Config file already exists! Not overwriting.
#   To add/change your token, edit 'hip_config.txt' directly.

# %%
# Function to read your token safely
def get_crawlbase_token():
    """Read token from config file"""
    try:
        with open('hip_config.txt', 'r') as f:
            lines = f.readlines()
            for line in lines:
                if line.startswith('CRAWLBASE_TOKEN='):
                    token = line.split('=')[1].strip()
                    return token
        print("Token not found in config file!")
        return None
    except FileNotFoundError:
        print("Config file not found! Run cell 3 first.")
        return None

# Test loading token
token = get_crawlbase_token()
if token and token != 'your_token_here':
    print("✓ Token loaded successfully!")
    print(f"Token starts with: {token[:10]}...")
else:
    print("✗ Please add your token to hip_config.txt")
# Out:
# ✓ Token loaded successfully!
# Token starts with: 8i_FkaiD6T...

# %%
# Let's build a URL for one test case
hotel = hotels[0]  # Pendry Manhattan West
check_in = datetime.now() + timedelta(days=7)  # 7 days from now
check_out = check_in + timedelta(days=1)  # Next day

# Format dates
check_in_str = check_in.strftime('%Y-%m-%d')
check_out_str = check_out.strftime('%Y-%m-%d')

# Build URL
base_url = f"https://www.expedia.com/New-York-Hotels-{hotel['name'].replace(' ', '-')}"
full_url = f"{base_url}.h{hotel['id']}.Hotel-Information?chkin={check_in_str}&chkout={check_out_str}"

print(f"Hotel: {hotel['name']}")
print(f"Check-in: {check_in_str}")
print(f"Check-out: {check_out_str}")
print(f"\nURL: {full_url[:100]}...")  # Show first 100 characters
# Out:
# Hotel: Pendry Manhattan West
# Check-in: 2025-08-06
# Check-out: 2025-08-07
#
# URL: https://www.expedia.com/New-York-Hotels-Pendry-Manhattan-West.h68272643.Hotel-Information?chkin=2025...

# %%
# Cell 6: Test Crawlbase Connection
def fetch_with_crawlbase(url, token):
    """Fetch a URL using Crawlbase API"""
    
    # Crawlbase API endpoint - note the specific format
    crawlbase_api = "https://api.crawlbase.com/"
    
    params = {
        'token': token,
        'url': url,
        'ajax_wait': 'true',  # Wait for JavaScript to load
        'page_wait': '5000'   # Wait 5 seconds for page to fully load
    }
    
    try:
        print(f"Fetching URL via Crawlbase...")
        print(f"Target URL: {url[:80]}...")  # Show first 80 chars
        
        response = requests.get(crawlbase_api, params=params)
        
        print(f"Response status: {response.status_code}")
        
        if response.status_code == 200:
            print("✓ Success! Page fetched.")
            return response.text
        else:
            print(f"✗ Error: Status code {response.status_code}")
            print(f"Response: {response.text[:200]}")  # Show error message
            return None
            
    except Exception as e:
        print(f"✗ Error: {e}")
        return None

# Test with our URL
token = get_crawlbase_token()  # Make sure we have the latest token
html = fetch_with_crawlbase(full_url, token)

if html:
    print(f"\nReceived HTML: {len(html)} characters")
    # Show a small preview
    print("\nFirst 500 characters:")
    print(html[:500])
else:
    print("\nNo HTML received. Check your token and try again.")
# Out:
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-Pendry-Manhattan-West.h68272643.Hotel-In...
# Response status: 200
# ✓ Success! Page fetched.
#
# Received HTML: 1264208 characters
#
# First 500 characters:
# <html data-language="en_US" dir="ltr" lang="en"><head><title>Pendry Manhattan West</title><link rel="canonical" href="https://www.expedia.com/New-York-Hotels-Pendry-Manhattan-West.h68272643.Hotel-Information"><link rel="preconnect" href="https://images.trvl-media.com/"><link rel="preconnect" href="https://maps.googleapis.com/"><link rel="preload" href="https://c.travel-assets.com/shopping-pwa/bernie.64c9ac0f82e08a5c53aa.js" as="script"><link rel="preload" href="https://c.travel-assets.com/shoppi

# %%
# Cell 7: Parse HTML to Find Price (with debugging)
print("Starting Cell 7...")

# Check if we have HTML
if 'html' not in globals():
    print("❌ 'html' variable not found. Please run Cell 6 first.")
elif html is None:
    print("❌ 'html' is None. Cell 6 didn't fetch the page successfully.")
elif len(html) == 0:
    print("❌ 'html' is empty.")
else:
    print(f"✓ HTML found: {len(html)} characters")
    
    soup = BeautifulSoup(html, 'html.parser')
    print("✓ HTML parsed with BeautifulSoup")
    
    # Find all text containing '$'
    price_texts = soup.find_all(text=lambda text: '$' in text if text else False)
    
    print(f"\nFound {len(price_texts)} elements with '$'")
    
    if len(price_texts) == 0:
        print("No dollar signs found in the HTML")
        # Let's try a different approach - look for common price classes
        price_elements = soup.find_all(['span', 'div'], class_=lambda x: x and 'price' in x.lower() if isinstance(x, str) else False)
        print(f"\nFound {len(price_elements)} elements with 'price' in class name")
    else:
        print("\nFirst 10 price-like texts:")
        count = 0
        for i, text in enumerate(price_texts):
            clean_text = text.strip()
            if clean_text and len(clean_text) < 50:
                if '$' in clean_text and any(char.isdigit() for char in clean_text):
                    count += 1
                    print(f"{count}: {clean_text}")
                    if count >= 10:
                        break
        
        if count == 0:
            print("No price-like text found (text with $ and numbers)")

print("\nCell 7 complete.")
# Out:
# Starting Cell 7...
# ✓ HTML found: 1264208 characters
# ✓ HTML parsed with BeautifulSoup
#
# Found 96 elements with '$'
#
# First 10 price-like texts:
# 1: + $0
# 2: + $46
# 3: $945 nightly
# 4: The current price is $1,088 total
# 5: $1,088 total
# 6: + $0
# 7: + $46
# 8: $945 nightly
# 9: The current price is $1,088 total
# 10: $1,088 total
#
# Cell 7 complete.
# C:\Users\bjlce\AppData\Local\Temp\ipykernel_36092\1193029050.py:18: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   price_texts = soup.find_all(text=lambda text: '$' in text if text else False)

# %%
# Cell 8: Extract Lowest Fully Refundable Rate
def extract_price_from_html(html):
    """
    Extract the lowest FULLY REFUNDABLE rate from Expedia HTML
    """
    soup = BeautifulSoup(html, 'html.parser')
    
    print("🔍 Searching for 'Fully refundable' rates...\n")
    
    # Find all text containing "Fully refundable"
    refundable_texts = soup.find_all(string=lambda text: text and 'fully refundable' in text.lower())
    
    print(f"Found {len(refundable_texts)} 'Fully refundable' mentions")
    
    prices = []
    
    for refund_text in refundable_texts:
        # Navigate up from "Fully refundable" text to find the container
        current = refund_text.parent
        
        # Go up the DOM tree to find the card/container with the price
        for _ in range(15):  # Check up to 15 levels
            if current:
                # Look for a nightly price in this container
                price_elem = current.find(string=lambda text: text and '$' in text and 'nightly' in text)
                
                if price_elem:
                    # Extract the price
                    import re
                    match = re.search(r'\$(\d+(?:,\d+)*)\s*nightly', price_elem)
                    if match:
                        price_str = match.group(1).replace(',', '')
                        price = float(price_str)
                        prices.append(price)
                        print(f"✓ Found fully refundable rate: ${price}")
                        break  # Found price for this refundable option
                
                current = current.parent
    
    if prices:
        # Remove duplicates and get the lowest
        unique_prices = list(set(prices))
        unique_prices.sort()
        lowest_price = unique_prices[0]
        
        print(f"\nUnique fully refundable rates: {unique_prices}")
        print(f"✅ Lowest fully refundable rate: ${lowest_price}")
        
        return lowest_price
    else:
        print("❌ No fully refundable rates found")
        return None

# Test the function
price = extract_price_from_html(html)

if price:
    print(f"\n✅ SUCCESS! Lowest fully refundable rate: ${price}")
else:
    print("\n❌ Could not find fully refundable rate")
# Out:
# 🔍 Searching for 'Fully refundable' rates...
#
# Found 23 'Fully refundable' mentions
# ✓ Found fully refundable rate: $945.0
# ✓ Found fully refundable rate: $945.0
# ✓ Found fully refundable rate: $1020.0
# ✓ Found fully refundable rate: $1170.0
# ✓ Found fully refundable rate: $1405.0
# ✓ Found fully refundable rate: $1480.0
# ✓ Found fully refundable rate: $1550.0
# ✓ Found fully refundable rate: $1550.0
# ✓ Found fully refundable rate: $1550.0
# ✓ Found fully refundable rate: $1635.0
# ✓ Found fully refundable rate: $1635.0
# ✓ Found fully refundable rate: $1885.0
# ✓ Found fully refundable rate: $1885.0
# ✓ Found fully refundable rate: $2225.0
# ✓ Found fully refundable rate: $2225.0
# ✓ Found fully refundable rate: $2440.0
# ✓ Found fully refundable rate: $2440.0
# ✓ Found fully refundable rate: $2440.0
# ✓ Found fully refundable rate: $2440.0
# ✓ Found fully refundable rate: $3290.0
# ✓ Found fully refundable rate: $3290.0
# ✓ Found fully refundable rate: $12000.0
# ✓ Found fully refundable rate: $12000.0
#
# Unique fully refundable rates: [945.0, 1020.0, 1170.0, 1405.0, 1480.0, 1550.0, 1635.0, 1885.0, 2225.0, 2440.0, 3290.0, 12000.0]
# ✅ Lowest fully refundable rate: $945.0
#
# ✅ SUCCESS! Lowest fully refundable rate: $945.0

# %%
def scrape_hotel_rate(hotel_name, hotel_id, check_in_date, token):
    """
    Scrape rate for one hotel on one date
    Returns a dictionary with the results
    """
    
    # Calculate check-out (next day)
    check_out_date = check_in_date + timedelta(days=1)
    
    # Format dates
    check_in_str = check_in_date.strftime('%Y-%m-%d')
    check_out_str = check_out_date.strftime('%Y-%m-%d')
    
    # Build URL
    hotel_url_name = hotel_name.replace(' ', '-')
    url = f"https://www.expedia.com/New-York-Hotels-{hotel_url_name}.h{hotel_id}.Hotel-Information"
    url += f"?chkin={check_in_str}&chkout={check_out_str}"
    
    # Fetch page
    html = fetch_with_crawlbase(url, token)
    
    # Extract price
    if html:
        price = extract_price_from_html(html)
        available = price is not None
    else:
        price = None
        available = False
    
    # Return results
    return {
        'hotel_name': hotel_name,
        'hotel_id': hotel_id,
        'check_in_date': check_in_str,
        'check_out_date': check_out_str,
        'price': price,
        'is_available': available,
        'scrape_timestamp': datetime.now().strftime('%Y-%m-%d %H:%M:%S'),
        'scrape_date': datetime.now().strftime('%Y-%m-%d')
    }

# Test with one hotel and date
test_result = scrape_hotel_rate(
    hotels[0]['name'], 
    hotels[0]['id'], 
    datetime.now() + timedelta(days=7),
    token
)

print("Scrape result:")
for key, value in test_result.items():
    print(f"  {key}: {value}")
# Out:
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-Pendry-Manhattan-West.h68272643.Hotel-In...
# Response status: 200
# ✓ Success! Page fetched.
# 🔍 Searching for 'Fully refundable' rates...
#
# Found 23 'Fully refundable' mentions
# ✓ Found fully refundable rate: $945.0
# ✓ Found fully refundable rate: $945.0
# ✓ Found fully refundable rate: $1020.0
# ✓ Found fully refundable rate: $1170.0
# ✓ Found fully refundable rate: $1405.0
# ✓ Found fully refundable rate: $1480.0
# ✓ Found fully refundable rate: $1550.0
# ✓ Found fully refundable rate: $1550.0
# ✓ Found fully refundable rate: $1550.0
# ✓ Found fully refundable rate: $1635.0
# ✓ Found fully refundable rate: $1635.0
# ✓ Found fully refundable rate: $1885.0
# ✓ Found fully refundable rate: $1885.0
# ✓ Found fully refundable rate: $2225.0
# ✓ Found fully refundable rate: $2225.0
# ✓ Found fully refundable rate: $2440.0
# ✓ Found fully refundable rate: $2440.0
# ✓ Found fully refundable rate: $2440.0
# ✓ Found fully refundable rate: $2440.0
# ✓ Found fully refundable rate: $3290.0
# ✓ Found fully refundable rate: $3290.0
# ✓ Found fully refundable rate: $12000.0
# ✓ Found fully refundable rate: $12000.0
#
# Unique fully refundable rates: [945.0, 1020.0, 1170.0, 1405.0, 1480.0, 1550.0, 1635.0, 1885.0, 2225.0, 2440.0, 3290.0, 12000.0]
# ✅ Lowest fully refundable rate: $945.0
# Scrape result:
#   hotel_name: Pendry Manhattan West
#   hotel_id: 68272643
#   check_in_date: 2025-08-06
#   check_out_date: 2025-08-07
#   price: 945.0
#   is_available: True
#   scrape_timestamp: 2025-07-30 10:48:39
#   scrape_date: 2025-07-30

# %%
# Cell 10: Scrape Multiple Dates for One Hotel
def scrape_hotel_all_dates(hotel_name, hotel_id, start_date, days_ahead, token):
    """
    Scrape rates for one hotel for multiple dates
    """
    results = []
    
    print(f"Scraping {hotel_name} for {days_ahead} days...")
    
    for day in range(days_ahead):
        check_in = start_date + timedelta(days=day)
        
        # Add small delay to be nice to the server
        if day > 0:
            time.sleep(2)  # Wait 2 seconds between requests
        
        print(f"  Day {day+1}/{days_ahead}: {check_in.strftime('%Y-%m-%d')}", end='')
        
        # Use the scrape_hotel_rate function which uses the correct extraction
        result = scrape_hotel_rate(hotel_name, hotel_id, check_in, token)
        results.append(result)
        
        if result['is_available']:
            print(f" - ${result['price']}")
        else:
            print(" - Not available")
    
    return results

# Test with one hotel for next 5 days
test_results = scrape_hotel_all_dates(
    hotels[0]['name'],
    hotels[0]['id'],
    datetime.now(),
    5,  # Just 5 days for testing
    token
)

# Convert to DataFrame for easy viewing
df_test = pd.DataFrame(test_results)
df_test
# Out:
# Scraping Pendry Manhattan West for 5 days...
#   Day 1/5: 2025-07-30Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-Pendry-Manhattan-West.h68272643.Hotel-In...
# Response status: 520
# ✗ Error: Status code 520
# Response: Request failed, with status codes original_status: 504 and pc_status: 0. Please try the request again, as this one is not charged, or contact support if the problem persists. If you want close to 100%
#  - Not available
#   Day 2/5: 2025-07-31Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-Pendry-Manhattan-West.h68272643.Hotel-In...
# Response status: 200
# ✓ Success! Page fetched.
# 🔍 Searching for 'Fully refundable' rates...
#
# Found 0 'Fully refundable' mentions
# ❌ No fully refundable rates found
#  - Not available
#   Day 3/5: 2025-08-01Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-Pendry-Manhattan-West.h68272643.Hotel-In...
# Response status: 200
# ✓ Success! Page fetched.
# 🔍 Searching for 'Fully refundable' rates...
#
# Found 15 'Fully refundable' mentions
# ✓ Found fully refundable rate: $795.0
# ✓ Found fully refundable rate: $870.0
# ✓ Found fully refundable rate: $1005.0
# ✓ Found fully refundable rate: $1095.0
# ✓ Found fully refundable rate: $1170.0
# ✓ Found fully refundable rate: $1220.0
# ✓ Found fully refundable rate: $1245.0
# ✓ Found fully refundable rate: $1295.0
# ✓ Found fully refundable rate: $1955.0
# ✓ Found fully refundable rate: $1955.0
# ✓ Found fully refundable rate: $2255.0
# ✓ Found fully refundable rate: $2445.0
# ✓ Found fully refundable rate: $2445.0
# ✓ Found fully refundable rate: $3195.0
# ✓ Found fully refundable rate: $12000.0
#
# Unique fully refundable rates: [795.0, 870.0, 1005.0, 1095.0, 1170.0, 1220.0, 1245.0, 1295.0, 1955.0, 2255.0, 2445.0, 3195.0, 12000.0]
# ✅ Lowest fully refundable rate: $795.0
#  - $795.0
#   Day 4/5: 2025-08-02Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-Pendry-Manhattan-West.h68272643.Hotel-In...
# Response status: 520
# ✗ Error: Status code 520
# Response: <html><head><title>Bot or Not?</title><meta charset="UTF-8"><meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"><meta name="viewport" content="width=device-width, initial-scale=1.0"><meta na
#  - Not available
#   Day 5/5: 2025-08-03Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-Pendry-Manhattan-West.h68272643.Hotel-In...
# Response status: 200
# ✓ Success! Page fetched.
# 🔍 Searching for 'Fully refundable' rates...
#
# Found 16 'Fully refundable' mentions
# ✓ Found fully refundable rate: $870.0
# ✓ Found fully refundable rate: $870.0
# ✓ Found fully refundable rate: $945.0
# ✓ Found fully refundable rate: $1020.0
# ✓ Found fully refundable rate: $1095.0
# ✓ Found fully refundable rate: $1170.0
# ✓ Found fully refundable rate: $1220.0
# ✓ Found fully refundable rate: $1220.0
# ✓ Found fully refundable rate: $1245.0
# ✓ Found fully refundable rate: $1295.0
# ✓ Found fully refundable rate: $1900.0
# ✓ Found fully refundable rate: $2200.0
# ✓ Found fully refundable rate: $2390.0
# ✓ Found fully refundable rate: $2390.0
# ✓ Found fully refundable rate: $3140.0
# ✓ Found fully refundable rate: $12000.0
#
# Unique fully refundable rates: [870.0, 945.0, 1020.0, 1095.0, 1170.0, 1220.0, 1245.0, 1295.0, 1900.0, 2200.0, 2390.0, 3140.0, 12000.0]
# ✅ Lowest fully refundable rate: $870.0
#  - $870.0
#               hotel_name  hotel_id check_in_date check_out_date  price  \
# 0  Pendry Manhattan West  68272643    2025-07-30     2025-07-31    NaN
# 1  Pendry Manhattan West  68272643    2025-07-31     2025-08-01    NaN
# 2  Pendry Manhattan West  68272643    2025-08-01     2025-08-02  795.0
# 3  Pendry Manhattan West  68272643    2025-08-02     2025-08-03    NaN
# 4  Pendry Manhattan West  68272643    2025-08-03     2025-08-04  870.0
#
#    is_available     scrape_timestamp scrape_date
# 0         False  2025-07-30 10:51:38  2025-07-30
# 1         False  2025-07-30 10:52:06  2025-07-30
# 2          True  2025-07-30 10:53:21  2025-07-30
# 3         False  2025-07-30 10:55:42  2025-07-30
# 4          True  2025-07-30 10:55:59  2025-07-30

# %%
# Cell 11: IMPROVED PARALLEL Version - Scrape All Hotels for 30 Days
import concurrent.futures
from concurrent.futures import ThreadPoolExecutor
import threading

# Thread-safe print function
print_lock = threading.Lock()

def safe_print(message):
    with print_lock:
        print(message)

def scrape_hotel_date_pair(hotel, check_in_date, token):
    """Scrape a single hotel/date combination"""
    try:
        result = scrape_hotel_rate(hotel['name'], hotel['id'], check_in_date, token)
        if result['is_available']:
            status = f"✓ ${result['price']}"
        else:
            status = "✗ N/A"
        safe_print(f"{hotel['name']} - {check_in_date.strftime('%Y-%m-%d')} {status}")
        return result
    except Exception as e:
        safe_print(f"Error: {hotel['name']} - {check_in_date.strftime('%Y-%m-%d')} - {str(e)[:50]}")
        return {
            'hotel_name': hotel['name'],
            'hotel_id': hotel['id'],
            'check_in_date': check_in_date.strftime('%Y-%m-%d'),
            'check_out_date': (check_in_date + timedelta(days=1)).strftime('%Y-%m-%d'),
            'price': None,
            'is_available': False,
            'scrape_timestamp': datetime.now().strftime('%Y-%m-%d %H:%M:%S'),
            'scrape_date': datetime.now().strftime('%Y-%m-%d'),
            'error': str(e)
        }

def scrape_all_hotels_parallel(hotels, days_ahead=30, max_workers=20):
    """
    Scrape all hotels in PARALLEL for speed
    Increased workers and removed progress printing for speed
    """
    
    # Get token
    token = get_crawlbase_token()
    if not token or token == 'your_token_here':
        print("❌ Error: Please set your Crawlbase token in hip_config.txt")
        return None
    
    # Starting date (today)
    start_date = datetime.now()
    
    # Create all hotel/date combinations
    tasks = []
    for hotel in hotels:
        for day in range(days_ahead):
            check_in = start_date + timedelta(days=day)
            tasks.append((hotel, check_in, token))
    
    total_tasks = len(tasks)
    print(f"Starting HIP Rate Scraping (PARALLEL)")
    print(f"Hotels: {len(hotels)}")
    print(f"Days: {days_ahead}")
    print(f"Total scrapes: {total_tasks}")
    print(f"Parallel workers: {max_workers}")
    print(f"Estimated time: {(total_tasks / max_workers * 8) / 60:.1f} minutes")
    print("-" * 50)
    
    # Execute in parallel
    all_results = []
    completed_count = 0
    
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        # Submit all tasks
        futures = []
        for task in tasks:
            future = executor.submit(scrape_hotel_date_pair, task[0], task[1], task[2])
            futures.append(future)
        
        # Process completed tasks
        for future in concurrent.futures.as_completed(futures):
            try:
                result = future.result()
                all_results.append(result)
                completed_count += 1
                
                # Print progress every 10 completions
                if completed_count % 10 == 0:
                    safe_print(f"Progress: {completed_count}/{total_tasks} ({completed_count/total_tasks*100:.0f}%)")
                    
            except Exception as e:
                safe_print(f"Task failed: {e}")
                completed_count += 1
    
    print("\n" + "="*50)
    print(f"✅ Scraping complete! {len(all_results)} results collected.")
    
    return all_results

# For TESTING: Use fewer days/hotels
# test_hotels = hotels[:2]  # First 2 hotels only
# test_days = 3  # Next 3 days only

# For FULL RUN: Use all hotels and days
test_hotels = hotels  # All 6 hotels
test_days = 30  # Next 30 days

print("🚀 PARALLEL SCRAPING - 6 hotels × 30 days")
results = scrape_all_hotels_parallel(test_hotels, days_ahead=test_days, max_workers=20)
# Out:
# 🚀 PARALLEL SCRAPING - 6 hotels × 30 days
# Starting HIP Rate Scraping (PARALLEL)
# Hotels: 6
# Days: 30
# Total scrapes: 180
# Parallel workers: 20
# Estimated time: 1.2 minutes
# --------------------------------------------------
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-Pendry-Manhattan-West.h68272643.Hotel-In...
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-Pendry-Manhattan-West.h68272643.Hotel-In...
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-Pendry-Manhattan-West.h68272643.Hotel-In...
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-Pendry-Manhattan-West.h68272643.Hotel-In...
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-Pendry-Manhattan-West.h68272643.Hotel-In...
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-Pendry-Manhattan-West.h68272643.Hotel-In...
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-Pendry-Manhattan-West.h68272643.Hotel-In...
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-Pendry-Manhattan-West.h68272643.Hotel-In...
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-Pendry-Manhattan-West.h68272643.Hotel-In...
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-Pendry-Manhattan-West.h68272643.Hotel-In...
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-Pendry-Manhattan-West.h68272643.Hotel-In...
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-Pendry-Manhattan-West.h68272643.Hotel-In...
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-Pendry-Manhattan-West.h68272643.Hotel-In...
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-Pendry-Manhattan-West.h68272643.Hotel-In...
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-Pendry-Manhattan-West.h68272643.Hotel-In...
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-Pendry-Manhattan-West.h68272643.Hotel-In...
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-Pendry-Manhattan-West.h68272643.Hotel-In...
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-Pendry-Manhattan-West.h68272643.Hotel-In...
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-Pendry-Manhattan-West.h68272643.Hotel-In...
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-Pendry-Manhattan-West.h68272643.Hotel-In...
# Response status: 200
# ✓ Success! Page fetched.
# 🔍 Searching for 'Fully refundable' rates...
#
# Found 16 'Fully refundable' mentions
# ✓ Found fully refundable rate: $870.0
# ✓ Found fully refundable rate: $870.0
# ✓ Found fully refundable rate: $945.0
# ✓ Found fully refundable rate: $1020.0
# ✓ Found fully refundable rate: $1095.0
# ✓ Found fully refundable rate: $1170.0
# ✓ Found fully refundable rate: $1220.0
# ✓ Found fully refundable rate: $1220.0
# ✓ Found fully refundable rate: $1245.0
# ✓ Found fully refundable rate: $1295.0
# ✓ Found fully refundable rate: $1900.0
# ✓ Found fully refundable rate: $2200.0
# ✓ Found fully refundable rate: $2390.0
# ✓ Found fully refundable rate: $2390.0
# ✓ Found fully refundable rate: $3140.0
# ✓ Found fully refundable rate: $12000.0
#
# Unique fully refundable rates: [870.0, 945.0, 1020.0, 1095.0, 1170.0, 1220.0, 1245.0, 1295.0, 1900.0, 2200.0, 2390.0, 3140.0, 12000.0]
# ✅ Lowest fully refundable rate: $870.0
# Pendry Manhattan West - 2025-08-03 ✓ $870.0
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-Pendry-Manhattan-West.h68272643.Hotel-In...
# Response status: 200
# ✓ Success! Page fetched.
# 🔍 Searching for 'Fully refundable' rates...
#
# Found 17 'Fully refundable' mentions
# ✓ Found fully refundable rate: $945.0
# ✓ Found fully refundable rate: $945.0
# ✓ Found fully refundable rate: $1020.0
# ✓ Found fully refundable rate: $1095.0
# ✓ Found fully refundable rate: $1095.0
# ✓ Found fully refundable rate: $1170.0
# ✓ Found fully refundable rate: $1420.0
# ✓ Found fully refundable rate: $1495.0
# ✓ Found fully refundable rate: $1560.0
# ✓ Found fully refundable rate: $1560.0
# ✓ Found fully refundable rate: $1645.0
# ✓ Found fully refundable rate: $2100.0
# ✓ Found fully refundable rate: $2440.0
# ✓ Found fully refundable rate: $3215.0
# ✓ Found fully refundable rate: $3215.0
# ✓ Found fully refundable rate: $4065.0
# ✓ Found fully refundable rate: $12000.0
#
# Unique fully refundable rates: [945.0, 1020.0, 1095.0, 1170.0, 1420.0, 1495.0, 1560.0, 1645.0, 2100.0, 2440.0, 3215.0, 4065.0, 12000.0]
# ✅ Lowest fully refundable rate: $945.0
# Pendry Manhattan West - 2025-08-05 ✓ $945.0
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-Pendry-Manhattan-West.h68272643.Hotel-In...
# Response status: 200
# ✓ Success! Page fetched.
# 🔍 Searching for 'Fully refundable' rates...
#
# Found 0 'Fully refundable' mentions
# ❌ No fully refundable rates found
# Pendry Manhattan West - 2025-07-30 ✗ N/A
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-Pendry-Manhattan-West.h68272643.Hotel-In...
# Response status: 200
# ✓ Success! Page fetched.
# 🔍 Searching for 'Fully refundable' rates...
#
# Found 13 'Fully refundable' mentions
# ✓ Found fully refundable rate: $795.0
# ✓ Found fully refundable rate: $795.0
# ✓ Found fully refundable rate: $870.0
# ✓ Found fully refundable rate: $1170.0
# ✓ Found fully refundable rate: $1220.0
# ✓ Found fully refundable rate: $1245.0
# ✓ Found fully refundable rate: $1295.0
# ✓ Found fully refundable rate: $1910.0
# ✓ Found fully refundable rate: $1910.0
# ✓ Found fully refundable rate: $2210.0
# ✓ Found fully refundable rate: $2400.0
# ✓ Found fully refundable rate: $3150.0
# ✓ Found fully refundable rate: $12000.0
#
# Unique fully refundable rates: [795.0, 870.0, 1170.0, 1220.0, 1245.0, 1295.0, 1910.0, 2210.0, 2400.0, 3150.0, 12000.0]
# ✅ Lowest fully refundable rate: $795.0
# Pendry Manhattan West - 2025-08-02 ✓ $795.0
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-Pendry-Manhattan-West.h68272643.Hotel-In...
# Response status: 200
# ✓ Success! Page fetched.
# 🔍 Searching for 'Fully refundable' rates...
#
# Found 26 'Fully refundable' mentions
# ✓ Found fully refundable rate: $675.0
# ✓ Found fully refundable rate: $675.0
# ✓ Found fully refundable rate: $740.0
# ✓ Found fully refundable rate: $855.0
# ✓ Found fully refundable rate: $930.0
# ✓ Found fully refundable rate: $995.0
# ✓ Found fully refundable rate: $1060.0
# ✓ Found fully refundable rate: $1220.0
# ✓ Found fully refundable rate: $1220.0
# ✓ Found fully refundable rate: $1220.0
# ✓ Found fully refundable rate: $1295.0
# ✓ Found fully refundable rate: $1295.0
# ✓ Found fully refundable rate: $1865.0
# ✓ Found fully refundable rate: $1865.0
# ✓ Found fully refundable rate: $1865.0
# ✓ Found fully refundable rate: $1865.0
# ✓ Found fully refundable rate: $2165.0
# ✓ Found fully refundable rate: $2165.0
# ✓ Found fully refundable rate: $2350.0
# ✓ Found fully refundable rate: $2350.0
# ✓ Found fully refundable rate: $2350.0
# ✓ Found fully refundable rate: $2350.0
# ✓ Found fully refundable rate: $3100.0
# ✓ Found fully refundable rate: $3100.0
# ✓ Found fully refundable rate: $12000.0
# ✓ Found fully refundable rate: $12000.0
#
# Unique fully refundable rates: [675.0, 740.0, 855.0, 930.0, 995.0, 1060.0, 1220.0, 1295.0, 1865.0, 2165.0, 2350.0, 3100.0, 12000.0]
# ✅ Lowest fully refundable rate: $675.0
# Pendry Manhattan West - 2025-08-15 ✓ $675.0
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-Pendry-Manhattan-West.h68272643.Hotel-In...
# Response status: 200
# ✓ Success! Page fetched.
# 🔍 Searching for 'Fully refundable' rates...
#
# Found 23 'Fully refundable' mentions
# ✓ Found fully refundable rate: $795.0
# ✓ Found fully refundable rate: $870.0
# ✓ Found fully refundable rate: $1005.0
# ✓ Found fully refundable rate: $1095.0
# ✓ Found fully refundable rate: $1170.0
# ✓ Found fully refundable rate: $1220.0
# ✓ Found fully refundable rate: $1220.0
# ✓ Found fully refundable rate: $1220.0
# ✓ Found fully refundable rate: $1245.0
# ✓ Found fully refundable rate: $1295.0
# ✓ Found fully refundable rate: $1295.0
# ✓ Found fully refundable rate: $1865.0
# ✓ Found fully refundable rate: $1865.0
# ✓ Found fully refundable rate: $2165.0
# ✓ Found fully refundable rate: $2165.0
# ✓ Found fully refundable rate: $2350.0
# ✓ Found fully refundable rate: $2350.0
# ✓ Found fully refundable rate: $2350.0
# ✓ Found fully refundable rate: $2350.0
# ✓ Found fully refundable rate: $3100.0
# ✓ Found fully refundable rate: $3100.0
# ✓ Found fully refundable rate: $12000.0
# ✓ Found fully refundable rate: $12000.0
#
# Unique fully refundable rates: [795.0, 870.0, 1005.0, 1095.0, 1170.0, 1220.0, 1245.0, 1295.0, 1865.0, 2165.0, 2350.0, 3100.0, 12000.0]
# ✅ Lowest fully refundable rate: $795.0
# Pendry Manhattan West - 2025-08-08 ✓ $795.0
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-Pendry-Manhattan-West.h68272643.Hotel-In...
# Response status: 200
# ✓ Success! Page fetched.
# 🔍 Searching for 'Fully refundable' rates...
#
# Found 27 'Fully refundable' mentions
# ✓ Found fully refundable rate: $900.0
# ✓ Found fully refundable rate: $900.0
# ✓ Found fully refundable rate: $975.0
# ✓ Found fully refundable rate: $1050.0
# ✓ Found fully refundable rate: $1050.0
# ✓ Found fully refundable rate: $1125.0
# ✓ Found fully refundable rate: $1200.0
# ✓ Found fully refundable rate: $1225.0
# ✓ Found fully refundable rate: $1225.0
# ✓ Found fully refundable rate: $1225.0
# ✓ Found fully refundable rate: $1275.0
# ✓ Found fully refundable rate: $1300.0
# ✓ Found fully refundable rate: $1300.0
# ✓ Found fully refundable rate: $1985.0
# ✓ Found fully refundable rate: $1985.0
# ✓ Found fully refundable rate: $1985.0
# ✓ Found fully refundable rate: $1985.0
# ✓ Found fully refundable rate: $2285.0
# ✓ Found fully refundable rate: $2285.0
# ✓ Found fully refundable rate: $2475.0
# ✓ Found fully refundable rate: $2475.0
# ✓ Found fully refundable rate: $2475.0
# ✓ Found fully refundable rate: $2475.0
# ✓ Found fully refundable rate: $3225.0
# ✓ Found fully refundable rate: $3225.0
# ✓ Found fully refundable rate: $12000.0
# ✓ Found fully refundable rate: $12000.0
#
# Unique fully refundable rates: [900.0, 975.0, 1050.0, 1125.0, 1200.0, 1225.0, 1275.0, 1300.0, 1985.0, 2285.0, 2475.0, 3225.0, 12000.0]
# ✅ Lowest fully refundable rate: $900.0
# Pendry Manhattan West - 2025-08-11 ✓ $900.0
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-Pendry-Manhattan-West.h68272643.Hotel-In...
# Response status: 200
# ✓ Success! Page fetched.
# 🔍 Searching for 'Fully refundable' rates...
#
# Found 22 'Fully refundable' mentions
# ✓ Found fully refundable rate: $840.0
# ✓ Found fully refundable rate: $905.0
# ✓ Found fully refundable rate: $970.0
# ✓ Found fully refundable rate: $1035.0
# ✓ Found fully refundable rate: $1100.0
# ✓ Found fully refundable rate: $1505.0
# ✓ Found fully refundable rate: $1505.0
# ✓ Found fully refundable rate: $1505.0
# ✓ Found fully refundable rate: $1590.0
# ✓ Found fully refundable rate: $1590.0
# ✓ Found fully refundable rate: $2185.0
# ✓ Found fully refundable rate: $2185.0
# ✓ Found fully refundable rate: $2185.0
# ✓ Found fully refundable rate: $2185.0
# ✓ Found fully refundable rate: $2525.0
# ✓ Found fully refundable rate: $2525.0
# ✓ Found fully refundable rate: $2735.0
# ✓ Found fully refundable rate: $2735.0
# ✓ Found fully refundable rate: $3585.0
# ✓ Found fully refundable rate: $3585.0
# ✓ Found fully refundable rate: $12000.0
# ✓ Found fully refundable rate: $12000.0
#
# Unique fully refundable rates: [840.0, 905.0, 970.0, 1035.0, 1100.0, 1505.0, 1590.0, 2185.0, 2525.0, 2735.0, 3585.0, 12000.0]
# ✅ Lowest fully refundable rate: $840.0
# Pendry Manhattan West - 2025-08-13 ✓ $840.0
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-Pendry-Manhattan-West.h68272643.Hotel-In...
# Response status: 200
# ✓ Success! Page fetched.
# 🔍 Searching for 'Fully refundable' rates...
#
# Found 26 'Fully refundable' mentions
# ✓ Found fully refundable rate: $760.0
# ✓ Found fully refundable rate: $760.0
# ✓ Found fully refundable rate: $825.0
# ✓ Found fully refundable rate: $910.0
# ✓ Found fully refundable rate: $975.0
# ✓ Found fully refundable rate: $1035.0
# ✓ Found fully refundable rate: $1100.0
# ✓ Found fully refundable rate: $1315.0
# ✓ Found fully refundable rate: $1315.0
# ✓ Found fully refundable rate: $1315.0
# ✓ Found fully refundable rate: $1390.0
# ✓ Found fully refundable rate: $1390.0
# ✓ Found fully refundable rate: $1925.0
# ✓ Found fully refundable rate: $1925.0
# ✓ Found fully refundable rate: $1925.0
# ✓ Found fully refundable rate: $1925.0
# ✓ Found fully refundable rate: $2225.0
# ✓ Found fully refundable rate: $2225.0
# ✓ Found fully refundable rate: $2410.0
# ✓ Found fully refundable rate: $2410.0
# ✓ Found fully refundable rate: $2410.0
# ✓ Found fully refundable rate: $2410.0
# ✓ Found fully refundable rate: $3160.0
# ✓ Found fully refundable rate: $3160.0
# ✓ Found fully refundable rate: $12000.0
# ✓ Found fully refundable rate: $12000.0
#
# Unique fully refundable rates: [760.0, 825.0, 910.0, 975.0, 1035.0, 1100.0, 1315.0, 1390.0, 1925.0, 2225.0, 2410.0, 3160.0, 12000.0]
# ✅ Lowest fully refundable rate: $760.0
# Pendry Manhattan West - 2025-08-21 ✓ $760.0
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-Pendry-Manhattan-West.h68272643.Hotel-In...
# Response status: 200
# ✓ Success! Page fetched.
# 🔍 Searching for 'Fully refundable' rates...
#
# Found 15 'Fully refundable' mentions
# ✓ Found fully refundable rate: $795.0
# ✓ Found fully refundable rate: $870.0
# ✓ Found fully refundable rate: $1005.0
# ✓ Found fully refundable rate: $1095.0
# ✓ Found fully refundable rate: $1170.0
# ✓ Found fully refundable rate: $1220.0
# ✓ Found fully refundable rate: $1245.0
# ✓ Found fully refundable rate: $1295.0
# ✓ Found fully refundable rate: $1955.0
# ✓ Found fully refundable rate: $1955.0
# ✓ Found fully refundable rate: $2255.0
# ✓ Found fully refundable rate: $2445.0
# ✓ Found fully refundable rate: $2445.0
# ✓ Found fully refundable rate: $3195.0
# ✓ Found fully refundable rate: $12000.0
#
# Unique fully refundable rates: [795.0, 870.0, 1005.0, 1095.0, 1170.0, 1220.0, 1245.0, 1295.0, 1955.0, 2255.0, 2445.0, 3195.0, 12000.0]
# ✅ Lowest fully refundable rate: $795.0
# Pendry Manhattan West - 2025-08-01 ✓ $795.0
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-Pendry-Manhattan-West.h68272643.Hotel-In...
# Progress: 10/180 (6%)
# Response status: 200
# ✓ Success! Page fetched.
# 🔍 Searching for 'Fully refundable' rates...
#
# Found 23 'Fully refundable' mentions
# ✓ Found fully refundable rate: $795.0
# ✓ Found fully refundable rate: $795.0
# ✓ Found fully refundable rate: $870.0
# ✓ Found fully refundable rate: $970.0
# ✓ Found fully refundable rate: $1045.0
# ✓ Found fully refundable rate: $1120.0
# ✓ Found fully refundable rate: $1195.0
# ✓ Found fully refundable rate: $1220.0
# ✓ Found fully refundable rate: $1220.0
# ✓ Found fully refundable rate: $1295.0
# ✓ Found fully refundable rate: $1295.0
# ✓ Found fully refundable rate: $1925.0
# ✓ Found fully refundable rate: $1925.0
# ✓ Found fully refundable rate: $2225.0
# ✓ Found fully refundable rate: $2225.0
# ✓ Found fully refundable rate: $2410.0
# ✓ Found fully refundable rate: $2410.0
# ✓ Found fully refundable rate: $2410.0
# ✓ Found fully refundable rate: $2410.0
# ✓ Found fully refundable rate: $3160.0
# ✓ Found fully refundable rate: $3160.0
# ✓ Found fully refundable rate: $12000.0
# ✓ Found fully refundable rate: $12000.0
#
# Unique fully refundable rates: [795.0, 870.0, 970.0, 1045.0, 1120.0, 1195.0, 1220.0, 1295.0, 1925.0, 2225.0, 2410.0, 3160.0, 12000.0]
# ✅ Lowest fully refundable rate: $795.0
# Pendry Manhattan West - 2025-08-07 ✓ $795.0
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-The-Mercer.h118588.Hotel-Information?chk...
# Response status: 200
# ✓ Success! Page fetched.
# 🔍 Searching for 'Fully refundable' rates...
#
# Found 24 'Fully refundable' mentions
# ✓ Found fully refundable rate: $650.0
# ✓ Found fully refundable rate: $650.0
# ✓ Found fully refundable rate: $715.0
# ✓ Found fully refundable rate: $835.0
# ✓ Found fully refundable rate: $905.0
# ✓ Found fully refundable rate: $970.0
# ✓ Found fully refundable rate: $1035.0
# ✓ Found fully refundable rate: $1200.0
# ✓ Found fully refundable rate: $1200.0
# ✓ Found fully refundable rate: $1200.0
# ✓ Found fully refundable rate: $1255.0
# ✓ Found fully refundable rate: $1255.0
# ✓ Found fully refundable rate: $1775.0
# ✓ Found fully refundable rate: $1775.0
# ✓ Found fully refundable rate: $2075.0
# ✓ Found fully refundable rate: $2075.0
# ✓ Found fully refundable rate: $2265.0
# ✓ Found fully refundable rate: $2265.0
# ✓ Found fully refundable rate: $2265.0
# ✓ Found fully refundable rate: $2265.0
# ✓ Found fully refundable rate: $3015.0
# ✓ Found fully refundable rate: $3015.0
# ✓ Found fully refundable rate: $12000.0
# ✓ Found fully refundable rate: $12000.0
#
# Unique fully refundable rates: [650.0, 715.0, 835.0, 905.0, 970.0, 1035.0, 1200.0, 1255.0, 1775.0, 2075.0, 2265.0, 3015.0, 12000.0]
# ✅ Lowest fully refundable rate: $650.0
# Pendry Manhattan West - 2025-08-23 ✓ $650.0
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-The-Mercer.h118588.Hotel-Information?chk...
# Response status: 200
# ✓ Success! Page fetched.
# 🔍 Searching for 'Fully refundable' rates...
#
# Found 27 'Fully refundable' mentions
# ✓ Found fully refundable rate: $695.0
# ✓ Found fully refundable rate: $695.0
# ✓ Found fully refundable rate: $755.0
# ✓ Found fully refundable rate: $820.0
# ✓ Found fully refundable rate: $820.0
# ✓ Found fully refundable rate: $885.0
# ✓ Found fully refundable rate: $950.0
# ✓ Found fully refundable rate: $1010.0
# ✓ Found fully refundable rate: $1200.0
# ✓ Found fully refundable rate: $1200.0
# ✓ Found fully refundable rate: $1200.0
# ✓ Found fully refundable rate: $1235.0
# ✓ Found fully refundable rate: $1235.0
# ✓ Found fully refundable rate: $1600.0
# ✓ Found fully refundable rate: $1600.0
# ✓ Found fully refundable rate: $1600.0
# ✓ Found fully refundable rate: $1600.0
# ✓ Found fully refundable rate: $1900.0
# ✓ Found fully refundable rate: $1900.0
# ✓ Found fully refundable rate: $2090.0
# ✓ Found fully refundable rate: $2090.0
# ✓ Found fully refundable rate: $2090.0
# ✓ Found fully refundable rate: $2090.0
# ✓ Found fully refundable rate: $2840.0
# ✓ Found fully refundable rate: $2840.0
# ✓ Found fully refundable rate: $12000.0
# ✓ Found fully refundable rate: $12000.0
#
# Unique fully refundable rates: [695.0, 755.0, 820.0, 885.0, 950.0, 1010.0, 1200.0, 1235.0, 1600.0, 1900.0, 2090.0, 2840.0, 12000.0]
# ✅ Lowest fully refundable rate: $695.0
# Pendry Manhattan West - 2025-08-17 ✓ $695.0
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-The-Mercer.h118588.Hotel-Information?chk...
# Response status: 200
# ✓ Success! Page fetched.
# 🔍 Searching for 'Fully refundable' rates...
#
# Found 25 'Fully refundable' mentions
# ✓ Found fully refundable rate: $700.0
# ✓ Found fully refundable rate: $700.0
# ✓ Found fully refundable rate: $765.0
# ✓ Found fully refundable rate: $830.0
# ✓ Found fully refundable rate: $830.0
# ✓ Found fully refundable rate: $895.0
# ✓ Found fully refundable rate: $955.0
# ✓ Found fully refundable rate: $1020.0
# ✓ Found fully refundable rate: $1200.0
# ✓ Found fully refundable rate: $1200.0
# ✓ Found fully refundable rate: $1200.0
# ✓ Found fully refundable rate: $1245.0
# ✓ Found fully refundable rate: $1245.0
# ✓ Found fully refundable rate: $1600.0
# ✓ Found fully refundable rate: $1600.0
# ✓ Found fully refundable rate: $1900.0
# ✓ Found fully refundable rate: $1900.0
# ✓ Found fully refundable rate: $2090.0
# ✓ Found fully refundable rate: $2090.0
# ✓ Found fully refundable rate: $2090.0
# ✓ Found fully refundable rate: $2090.0
# ✓ Found fully refundable rate: $2840.0
# ✓ Found fully refundable rate: $2840.0
# ✓ Found fully refundable rate: $12000.0
# ✓ Found fully refundable rate: $12000.0
#
# Unique fully refundable rates: [700.0, 765.0, 830.0, 895.0, 955.0, 1020.0, 1200.0, 1245.0, 1600.0, 1900.0, 2090.0, 2840.0, 12000.0]
# ✅ Lowest fully refundable rate: $700.0
# Pendry Manhattan West - 2025-08-24 ✓ $700.0
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-The-Mercer.h118588.Hotel-Information?chk...
# Response status: 200
# ✓ Success! Page fetched.
# 🔍 Searching for 'Fully refundable' rates...
#
# Found 26 'Fully refundable' mentions
# ✓ Found fully refundable rate: $650.0
# ✓ Found fully refundable rate: $715.0
# ✓ Found fully refundable rate: $830.0
# ✓ Found fully refundable rate: $830.0
# ✓ Found fully refundable rate: $905.0
# ✓ Found fully refundable rate: $970.0
# ✓ Found fully refundable rate: $1035.0
# ✓ Found fully refundable rate: $1200.0
# ✓ Found fully refundable rate: $1200.0
# ✓ Found fully refundable rate: $1200.0
# ✓ Found fully refundable rate: $1255.0
# ✓ Found fully refundable rate: $1255.0
# ✓ Found fully refundable rate: $1825.0
# ✓ Found fully refundable rate: $1825.0
# ✓ Found fully refundable rate: $1825.0
# ✓ Found fully refundable rate: $1825.0
# ✓ Found fully refundable rate: $2125.0
# ✓ Found fully refundable rate: $2125.0
# ✓ Found fully refundable rate: $2330.0
# ✓ Found fully refundable rate: $2330.0
# ✓ Found fully refundable rate: $2330.0
# ✓ Found fully refundable rate: $2330.0
# ✓ Found fully refundable rate: $3080.0
# ✓ Found fully refundable rate: $3080.0
# ✓ Found fully refundable rate: $12000.0
# ✓ Found fully refundable rate: $12000.0
#
# Unique fully refundable rates: [650.0, 715.0, 830.0, 905.0, 970.0, 1035.0, 1200.0, 1255.0, 1825.0, 2125.0, 2330.0, 3080.0, 12000.0]
# ✅ Lowest fully refundable rate: $650.0
# Pendry Manhattan West - 2025-08-22 ✓ $650.0
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-The-Mercer.h118588.Hotel-Information?chk...
# Response status: 200
# ✓ Success! Page fetched.
# 🔍 Searching for 'Fully refundable' rates...
#
# Found 22 'Fully refundable' mentions
# ✓ Found fully refundable rate: $995.0
# ✓ Found fully refundable rate: $995.0
# ✓ Found fully refundable rate: $1060.0
# ✓ Found fully refundable rate: $1125.0
# ✓ Found fully refundable rate: $1125.0
# ✓ Found fully refundable rate: $1195.0
# ✓ Found fully refundable rate: $1680.0
# ✓ Found fully refundable rate: $1745.0
# ✓ Found fully refundable rate: $2345.0
# ✓ Found fully refundable rate: $2345.0
# ✓ Found fully refundable rate: $2445.0
# ✓ Found fully refundable rate: $2445.0
# ✓ Found fully refundable rate: $2670.0
# ✓ Found fully refundable rate: $3020.0
# ✓ Found fully refundable rate: $3020.0
# ✓ Found fully refundable rate: $3420.0
# ✓ Found fully refundable rate: $3420.0
# ✓ Found fully refundable rate: $3670.0
# ✓ Found fully refundable rate: $3670.0
# ✓ Found fully refundable rate: $4670.0
# ✓ Found fully refundable rate: $12000.0
# ✓ Found fully refundable rate: $12000.0
#
# Unique fully refundable rates: [995.0, 1060.0, 1125.0, 1195.0, 1680.0, 1745.0, 2345.0, 2445.0, 2670.0, 3020.0, 3420.0, 3670.0, 4670.0, 12000.0]
# ✅ Lowest fully refundable rate: $995.0
# Pendry Manhattan West - 2025-08-27 ✓ $995.0
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-The-Mercer.h118588.Hotel-Information?chk...
# Response status: 200
# ✓ Success! Page fetched.
# 🔍 Searching for 'Fully refundable' rates...
#
# Found 26 'Fully refundable' mentions
# ✓ Found fully refundable rate: $810.0
# ✓ Found fully refundable rate: $810.0
# ✓ Found fully refundable rate: $875.0
# ✓ Found fully refundable rate: $940.0
# ✓ Found fully refundable rate: $1005.0
# ✓ Found fully refundable rate: $1200.0
# ✓ Found fully refundable rate: $1265.0
# ✓ Found fully refundable rate: $1765.0
# ✓ Found fully refundable rate: $1765.0
# ✓ Found fully refundable rate: $1765.0
# ✓ Found fully refundable rate: $1850.0
# ✓ Found fully refundable rate: $1850.0
# ✓ Found fully refundable rate: $2060.0
# ✓ Found fully refundable rate: $2060.0
# ✓ Found fully refundable rate: $2060.0
# ✓ Found fully refundable rate: $2060.0
# ✓ Found fully refundable rate: $2405.0
# ✓ Found fully refundable rate: $2405.0
# ✓ Found fully refundable rate: $2620.0
# ✓ Found fully refundable rate: $2620.0
# ✓ Found fully refundable rate: $2620.0
# ✓ Found fully refundable rate: $2620.0
# ✓ Found fully refundable rate: $3470.0
# ✓ Found fully refundable rate: $3470.0
# ✓ Found fully refundable rate: $12000.0
# ✓ Found fully refundable rate: $12000.0
#
# Unique fully refundable rates: [810.0, 875.0, 940.0, 1005.0, 1200.0, 1265.0, 1765.0, 1850.0, 2060.0, 2405.0, 2620.0, 3470.0, 12000.0]
# ✅ Lowest fully refundable rate: $810.0
# Pendry Manhattan West - 2025-08-20 ✓ $810.0
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-The-Mercer.h118588.Hotel-Information?chk...
# Response status: 200
# ✓ Success! Page fetched.
# 🔍 Searching for 'Fully refundable' rates...
#
# Found 24 'Fully refundable' mentions
# ✓ Found fully refundable rate: $750.0
# ✓ Found fully refundable rate: $815.0
# ✓ Found fully refundable rate: $880.0
# ✓ Found fully refundable rate: $880.0
# ✓ Found fully refundable rate: $945.0
# ✓ Found fully refundable rate: $1005.0
# ✓ Found fully refundable rate: $1070.0
# ✓ Found fully refundable rate: $1210.0
# ✓ Found fully refundable rate: $1210.0
# ✓ Found fully refundable rate: $1210.0
# ✓ Found fully refundable rate: $1285.0
# ✓ Found fully refundable rate: $1285.0
# ✓ Found fully refundable rate: $1795.0
# ✓ Found fully refundable rate: $1795.0
# ✓ Found fully refundable rate: $2095.0
# ✓ Found fully refundable rate: $2095.0
# ✓ Found fully refundable rate: $2375.0
# ✓ Found fully refundable rate: $2375.0
# ✓ Found fully refundable rate: $2375.0
# ✓ Found fully refundable rate: $2375.0
# ✓ Found fully refundable rate: $3125.0
# ✓ Found fully refundable rate: $3125.0
# ✓ Found fully refundable rate: $12000.0
# ✓ Found fully refundable rate: $12000.0
#
# Unique fully refundable rates: [750.0, 815.0, 880.0, 945.0, 1005.0, 1070.0, 1210.0, 1285.0, 1795.0, 2095.0, 2375.0, 3125.0, 12000.0]
# ✅ Lowest fully refundable rate: $750.0
# Pendry Manhattan West - 2025-08-18 ✓ $750.0
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-The-Mercer.h118588.Hotel-Information?chk...
# Response status: 200
# ✓ Success! Page fetched.
# 🔍 Searching for 'Fully refundable' rates...
#
# Found 0 'Fully refundable' mentions
# ❌ No fully refundable rates found
# Pendry Manhattan West - 2025-07-31 ✗ N/A
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-The-Mercer.h118588.Hotel-Information?chk...
# Response status: 520
# ✗ Error: Status code 520
# Response: <html><head><title>Bot or Not?</title><meta charset="UTF-8"><meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"><meta name="viewport" content="width=device-width, initial-scale=1.0"><meta na
# Pendry Manhattan West - 2025-08-14 ✗ N/A
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-The-Mercer.h118588.Hotel-Information?chk...
# Progress: 20/180 (11%)
# Response status: 200
# ✓ Success! Page fetched.
# 🔍 Searching for 'Fully refundable' rates...
#
# Found 25 'Fully refundable' mentions
# ✓ Found fully refundable rate: $960.0
# ✓ Found fully refundable rate: $960.0
# ✓ Found fully refundable rate: $1025.0
# ✓ Found fully refundable rate: $1090.0
# ✓ Found fully refundable rate: $1090.0
# ✓ Found fully refundable rate: $1155.0
# ✓ Found fully refundable rate: $1545.0
# ✓ Found fully refundable rate: $1610.0
# ✓ Found fully refundable rate: $2235.0
# ✓ Found fully refundable rate: $2235.0
# ✓ Found fully refundable rate: $2235.0
# ✓ Found fully refundable rate: $2325.0
# ✓ Found fully refundable rate: $2325.0
# ✓ Found fully refundable rate: $2615.0
# ✓ Found fully refundable rate: $2615.0
# ✓ Found fully refundable rate: $2965.0
# ✓ Found fully refundable rate: $2965.0
# ✓ Found fully refundable rate: $3995.0
# ✓ Found fully refundable rate: $3995.0
# ✓ Found fully refundable rate: $3995.0
# ✓ Found fully refundable rate: $3995.0
# ✓ Found fully refundable rate: $4865.0
# ✓ Found fully refundable rate: $4865.0
# ✓ Found fully refundable rate: $12000.0
# ✓ Found fully refundable rate: $12000.0
#
# Unique fully refundable rates: [960.0, 1025.0, 1090.0, 1155.0, 1545.0, 1610.0, 2235.0, 2325.0, 2615.0, 2965.0, 3995.0, 4865.0, 12000.0]
# ✅ Lowest fully refundable rate: $960.0
# Pendry Manhattan West - 2025-08-26 ✓ $960.0
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-The-Mercer.h118588.Hotel-Information?chk...
# Response status: 200
# ✓ Success! Page fetched.
# 🔍 Searching for 'Fully refundable' rates...
#
# Found 25 'Fully refundable' mentions
# ✓ Found fully refundable rate: $675.0
# ✓ Found fully refundable rate: $675.0
# ✓ Found fully refundable rate: $740.0
# ✓ Found fully refundable rate: $930.0
# ✓ Found fully refundable rate: $995.0
# ✓ Found fully refundable rate: $1060.0
# ✓ Found fully refundable rate: $1220.0
# ✓ Found fully refundable rate: $1220.0
# ✓ Found fully refundable rate: $1220.0
# ✓ Found fully refundable rate: $1295.0
# ✓ Found fully refundable rate: $1295.0
# ✓ Found fully refundable rate: $1865.0
# ✓ Found fully refundable rate: $1865.0
# ✓ Found fully refundable rate: $1865.0
# ✓ Found fully refundable rate: $1865.0
# ✓ Found fully refundable rate: $2165.0
# ✓ Found fully refundable rate: $2165.0
# ✓ Found fully refundable rate: $2350.0
# ✓ Found fully refundable rate: $2350.0
# ✓ Found fully refundable rate: $2350.0
# ✓ Found fully refundable rate: $2350.0
# ✓ Found fully refundable rate: $3100.0
# ✓ Found fully refundable rate: $3100.0
# ✓ Found fully refundable rate: $12000.0
# ✓ Found fully refundable rate: $12000.0
#
# Unique fully refundable rates: [675.0, 740.0, 930.0, 995.0, 1060.0, 1220.0, 1295.0, 1865.0, 2165.0, 2350.0, 3100.0, 12000.0]
# ✅ Lowest fully refundable rate: $675.0
# Pendry Manhattan West - 2025-08-16 ✓ $675.0
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-The-Mercer.h118588.Hotel-Information?chk...
# Response status: 200
# ✓ Success! Page fetched.
# 🔍 Searching for 'Fully refundable' rates...
#
# Found 5 'Fully refundable' mentions
# ✓ Found fully refundable rate: $875.0
# ✓ Found fully refundable rate: $925.0
# ✓ Found fully refundable rate: $1125.0
# ✓ Found fully refundable rate: $1275.0
# ✓ Found fully refundable rate: $1425.0
#
# Unique fully refundable rates: [875.0, 925.0, 1125.0, 1275.0, 1425.0]
# ✅ Lowest fully refundable rate: $875.0
# The Mercer - 2025-08-07 ✓ $875.0
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-The-Mercer.h118588.Hotel-Information?chk...
# Response status: 200
# ✓ Success! Page fetched.
# 🔍 Searching for 'Fully refundable' rates...
#
# Found 24 'Fully refundable' mentions
# ✓ Found fully refundable rate: $760.0
# ✓ Found fully refundable rate: $825.0
# ✓ Found fully refundable rate: $890.0
# ✓ Found fully refundable rate: $890.0
# ✓ Found fully refundable rate: $950.0
# ✓ Found fully refundable rate: $1075.0
# ✓ Found fully refundable rate: $1140.0
# ✓ Found fully refundable rate: $1355.0
# ✓ Found fully refundable rate: $1355.0
# ✓ Found fully refundable rate: $1355.0
# ✓ Found fully refundable rate: $1430.0
# ✓ Found fully refundable rate: $1430.0
# ✓ Found fully refundable rate: $1765.0
# ✓ Found fully refundable rate: $1765.0
# ✓ Found fully refundable rate: $2065.0
# ✓ Found fully refundable rate: $2065.0
# ✓ Found fully refundable rate: $2460.0
# ✓ Found fully refundable rate: $2460.0
# ✓ Found fully refundable rate: $2460.0
# ✓ Found fully refundable rate: $2460.0
# ✓ Found fully refundable rate: $3210.0
# ✓ Found fully refundable rate: $3210.0
# ✓ Found fully refundable rate: $12000.0
# ✓ Found fully refundable rate: $12000.0
#
# Unique fully refundable rates: [760.0, 825.0, 890.0, 950.0, 1075.0, 1140.0, 1355.0, 1430.0, 1765.0, 2065.0, 2460.0, 3210.0, 12000.0]
# ✅ Lowest fully refundable rate: $760.0
# Pendry Manhattan West - 2025-08-25 ✓ $760.0
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-The-Mercer.h118588.Hotel-Information?chk...
# Response status: 200
# ✓ Success! Page fetched.
# 🔍 Searching for 'Fully refundable' rates...
#
# Found 6 'Fully refundable' mentions
# ✓ Found fully refundable rate: $875.0
# ✓ Found fully refundable rate: $925.0
# ✓ Found fully refundable rate: $975.0
# ✓ Found fully refundable rate: $1125.0
# ✓ Found fully refundable rate: $1275.0
# ✓ Found fully refundable rate: $1425.0
#
# Unique fully refundable rates: [875.0, 925.0, 975.0, 1125.0, 1275.0, 1425.0]
# ✅ Lowest fully refundable rate: $875.0
# The Mercer - 2025-08-09 ✓ $875.0
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-The-Mercer.h118588.Hotel-Information?chk...
# Response status: 200
# ✓ Success! Page fetched.
# 🔍 Searching for 'Fully refundable' rates...
#
# Found 26 'Fully refundable' mentions
# ✓ Found fully refundable rate: $965.0
# ✓ Found fully refundable rate: $965.0
# ✓ Found fully refundable rate: $1040.0
# ✓ Found fully refundable rate: $1115.0
# ✓ Found fully refundable rate: $1190.0
# ✓ Found fully refundable rate: $1265.0
# ✓ Found fully refundable rate: $1340.0
# ✓ Found fully refundable rate: $1530.0
# ✓ Found fully refundable rate: $1530.0
# ✓ Found fully refundable rate: $1530.0
# ✓ Found fully refundable rate: $1615.0
# ✓ Found fully refundable rate: $1615.0
# ✓ Found fully refundable rate: $2420.0
# ✓ Found fully refundable rate: $2420.0
# ✓ Found fully refundable rate: $2420.0
# ✓ Found fully refundable rate: $2420.0
# ✓ Found fully refundable rate: $2760.0
# ✓ Found fully refundable rate: $2760.0
# ✓ Found fully refundable rate: $2975.0
# ✓ Found fully refundable rate: $2975.0
# ✓ Found fully refundable rate: $2975.0
# ✓ Found fully refundable rate: $2975.0
# ✓ Found fully refundable rate: $3825.0
# ✓ Found fully refundable rate: $3825.0
# ✓ Found fully refundable rate: $12000.0
# ✓ Found fully refundable rate: $12000.0
#
# Unique fully refundable rates: [965.0, 1040.0, 1115.0, 1190.0, 1265.0, 1340.0, 1530.0, 1615.0, 2420.0, 2760.0, 2975.0, 3825.0, 12000.0]
# ✅ Lowest fully refundable rate: $965.0
# Pendry Manhattan West - 2025-08-12 ✓ $965.0
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-The-Mercer.h118588.Hotel-Information?chk...
# Response status: 520
# ✗ Error: Status code 520
# Response: <html><head><title>Bot or Not?</title><meta charset="UTF-8"><meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"><meta name="viewport" content="width=device-width, initial-scale=1.0"><meta na
# Pendry Manhattan West - 2025-08-04 ✗ N/A
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-The-Mercer.h118588.Hotel-Information?chk...
# Response status: 200
# ✓ Success! Page fetched.
# 🔍 Searching for 'Fully refundable' rates...
#
# Found 6 'Fully refundable' mentions
# ✓ Found fully refundable rate: $875.0
# ✓ Found fully refundable rate: $925.0
# ✓ Found fully refundable rate: $975.0
# ✓ Found fully refundable rate: $1125.0
# ✓ Found fully refundable rate: $1275.0
# ✓ Found fully refundable rate: $1425.0
#
# Unique fully refundable rates: [875.0, 925.0, 975.0, 1125.0, 1275.0, 1425.0]
# ✅ Lowest fully refundable rate: $875.0
# The Mercer - 2025-08-08 ✓ $875.0
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-The-Mercer.h118588.Hotel-Information?chk...
# Response status: 200
# ✓ Success! Page fetched.
# 🔍 Searching for 'Fully refundable' rates...
#
# Found 6 'Fully refundable' mentions
# ✓ Found fully refundable rate: $875.0
# ✓ Found fully refundable rate: $925.0
# ✓ Found fully refundable rate: $975.0
# ✓ Found fully refundable rate: $1125.0
# ✓ Found fully refundable rate: $1275.0
# ✓ Found fully refundable rate: $1425.0
#
# Unique fully refundable rates: [875.0, 925.0, 975.0, 1125.0, 1275.0, 1425.0]
# ✅ Lowest fully refundable rate: $875.0
# The Mercer - 2025-08-13 ✓ $875.0
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-The-Mercer.h118588.Hotel-Information?chk...
# Response status: 200
# ✓ Success! Page fetched.
# 🔍 Searching for 'Fully refundable' rates...
#
# Found 6 'Fully refundable' mentions
# ✓ Found fully refundable rate: $875.0
# ✓ Found fully refundable rate: $925.0
# ✓ Found fully refundable rate: $975.0
# ✓ Found fully refundable rate: $1125.0
# ✓ Found fully refundable rate: $1275.0
# ✓ Found fully refundable rate: $1425.0
#
# Unique fully refundable rates: [875.0, 925.0, 975.0, 1125.0, 1275.0, 1425.0]
# ✅ Lowest fully refundable rate: $875.0
# The Mercer - 2025-08-10 ✓ $875.0
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-The-Mercer.h118588.Hotel-Information?chk...
# Progress: 30/180 (17%)
# Response status: 200
# ✓ Success! Page fetched.
# 🔍 Searching for 'Fully refundable' rates...
#
# Found 27 'Fully refundable' mentions
# ✓ Found fully refundable rate: $900.0
# ✓ Found fully refundable rate: $900.0
# ✓ Found fully refundable rate: $975.0
# ✓ Found fully refundable rate: $1050.0
# ✓ Found fully refundable rate: $1050.0
# ✓ Found fully refundable rate: $1125.0
# ✓ Found fully refundable rate: $1200.0
# ✓ Found fully refundable rate: $1225.0
# ✓ Found fully refundable rate: $1225.0
# ✓ Found fully refundable rate: $1225.0
# ✓ Found fully refundable rate: $1275.0
# ✓ Found fully refundable rate: $1300.0
# ✓ Found fully refundable rate: $1300.0
# ✓ Found fully refundable rate: $1865.0
# ✓ Found fully refundable rate: $1865.0
# ✓ Found fully refundable rate: $1865.0
# ✓ Found fully refundable rate: $1865.0
# ✓ Found fully refundable rate: $2165.0
# ✓ Found fully refundable rate: $2165.0
# ✓ Found fully refundable rate: $2350.0
# ✓ Found fully refundable rate: $2350.0
# ✓ Found fully refundable rate: $2350.0
# ✓ Found fully refundable rate: $2350.0
# ✓ Found fully refundable rate: $3100.0
# ✓ Found fully refundable rate: $3100.0
# ✓ Found fully refundable rate: $12000.0
# ✓ Found fully refundable rate: $12000.0
#
# Unique fully refundable rates: [900.0, 975.0, 1050.0, 1125.0, 1200.0, 1225.0, 1275.0, 1300.0, 1865.0, 2165.0, 2350.0, 3100.0, 12000.0]
# ✅ Lowest fully refundable rate: $900.0
# Pendry Manhattan West - 2025-08-10 ✓ $900.0
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-The-Mercer.h118588.Hotel-Information?chk...
# Response status: 200
# ✓ Success! Page fetched.
# 🔍 Searching for 'Fully refundable' rates...
#
# Found 6 'Fully refundable' mentions
# ✓ Found fully refundable rate: $875.0
# ✓ Found fully refundable rate: $925.0
# ✓ Found fully refundable rate: $975.0
# ✓ Found fully refundable rate: $1125.0
# ✓ Found fully refundable rate: $1275.0
# ✓ Found fully refundable rate: $1425.0
#
# Unique fully refundable rates: [875.0, 925.0, 975.0, 1125.0, 1275.0, 1425.0]
# ✅ Lowest fully refundable rate: $875.0
# The Mercer - 2025-08-03 ✓ $875.0
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-The-Mercer.h118588.Hotel-Information?chk...
# Response status: 200
# ✓ Success! Page fetched.
# 🔍 Searching for 'Fully refundable' rates...
#
# Found 24 'Fully refundable' mentions
# ✓ Found fully refundable rate: $895.0
# ✓ Found fully refundable rate: $895.0
# ✓ Found fully refundable rate: $965.0
# ✓ Found fully refundable rate: $1055.0
# ✓ Found fully refundable rate: $1120.0
# ✓ Found fully refundable rate: $1395.0
# ✓ Found fully refundable rate: $1465.0
# ✓ Found fully refundable rate: $1490.0
# ✓ Found fully refundable rate: $1490.0
# ✓ Found fully refundable rate: $1490.0
# ✓ Found fully refundable rate: $1565.0
# ✓ Found fully refundable rate: $1565.0
# ✓ Found fully refundable rate: $1770.0
# ✓ Found fully refundable rate: $1770.0
# ✓ Found fully refundable rate: $2070.0
# ✓ Found fully refundable rate: $2070.0
# ✓ Found fully refundable rate: $2255.0
# ✓ Found fully refundable rate: $2255.0
# ✓ Found fully refundable rate: $2255.0
# ✓ Found fully refundable rate: $2255.0
# ✓ Found fully refundable rate: $3005.0
# ✓ Found fully refundable rate: $3005.0
# ✓ Found fully refundable rate: $12000.0
# ✓ Found fully refundable rate: $12000.0
#
# Unique fully refundable rates: [895.0, 965.0, 1055.0, 1120.0, 1395.0, 1465.0, 1490.0, 1565.0, 1770.0, 2070.0, 2255.0, 3005.0, 12000.0]
# ✅ Lowest fully refundable rate: $895.0
# Pendry Manhattan West - 2025-08-28 ✓ $895.0
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-The-Mercer.h118588.Hotel-Information?chk...
# Response status: 200
# ✓ Success! Page fetched.
# 🔍 Searching for 'Fully refundable' rates...
#
# Found 4 'Fully refundable' mentions
# ✓ Found fully refundable rate: $875.0
# ✓ Found fully refundable rate: $1125.0
# ✓ Found fully refundable rate: $1275.0
# ✓ Found fully refundable rate: $1425.0
#
# Unique fully refundable rates: [875.0, 1125.0, 1275.0, 1425.0]
# ✅ Lowest fully refundable rate: $875.0
# The Mercer - 2025-08-18 ✓ $875.0
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-The-Mercer.h118588.Hotel-Information?chk...
# Response status: 200
# ✓ Success! Page fetched.
# 🔍 Searching for 'Fully refundable' rates...
#
# Found 25 'Fully refundable' mentions
# ✓ Found fully refundable rate: $795.0
# ✓ Found fully refundable rate: $795.0
# ✓ Found fully refundable rate: $870.0
# ✓ Found fully refundable rate: $1095.0
# ✓ Found fully refundable rate: $1170.0
# ✓ Found fully refundable rate: $1220.0
# ✓ Found fully refundable rate: $1220.0
# ✓ Found fully refundable rate: $1220.0
# ✓ Found fully refundable rate: $1245.0
# ✓ Found fully refundable rate: $1295.0
# ✓ Found fully refundable rate: $1295.0
# ✓ Found fully refundable rate: $1865.0
# ✓ Found fully refundable rate: $1865.0
# ✓ Found fully refundable rate: $1865.0
# ✓ Found fully refundable rate: $1865.0
# ✓ Found fully refundable rate: $2165.0
# ✓ Found fully refundable rate: $2165.0
# ✓ Found fully refundable rate: $2350.0
# ✓ Found fully refundable rate: $2350.0
# ✓ Found fully refundable rate: $2350.0
# ✓ Found fully refundable rate: $2350.0
# ✓ Found fully refundable rate: $3100.0
# ✓ Found fully refundable rate: $3100.0
# ✓ Found fully refundable rate: $12000.0
# ✓ Found fully refundable rate: $12000.0
#
# Unique fully refundable rates: [795.0, 870.0, 1095.0, 1170.0, 1220.0, 1245.0, 1295.0, 1865.0, 2165.0, 2350.0, 3100.0, 12000.0]
# ✅ Lowest fully refundable rate: $795.0
# Pendry Manhattan West - 2025-08-09 ✓ $795.0
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-The-Mercer.h118588.Hotel-Information?chk...
# Response status: 200
# ✓ Success! Page fetched.
# 🔍 Searching for 'Fully refundable' rates...
#
# Found 2 'Fully refundable' mentions
# ✓ Found fully refundable rate: $1275.0
# ✓ Found fully refundable rate: $1425.0
#
# Unique fully refundable rates: [1275.0, 1425.0]
# ✅ Lowest fully refundable rate: $1275.0
# The Mercer - 2025-08-20 ✓ $1275.0
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-The-Mercer.h118588.Hotel-Information?chk...
# Response status: 200
# ✓ Success! Page fetched.
# 🔍 Searching for 'Fully refundable' rates...
#
# Found 3 'Fully refundable' mentions
# ✓ Found fully refundable rate: $925.0
# ✓ Found fully refundable rate: $1275.0
# ✓ Found fully refundable rate: $1425.0
#
# Unique fully refundable rates: [925.0, 1275.0, 1425.0]
# ✅ Lowest fully refundable rate: $925.0
# The Mercer - 2025-08-21 ✓ $925.0
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-The-Mercer.h118588.Hotel-Information?chk...
# Response status: 520
# ✗ Error: Status code 520
# Response: Request failed, with status codes original_status: 504 and pc_status: 530. Please try the request again, as this one is not charged, or contact support if the problem persists. If you want close to 10
# The Mercer - 2025-08-01 ✗ N/A
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-The-Mercer.h118588.Hotel-Information?chk...
# Response status: 200
# ✓ Success! Page fetched.
# 🔍 Searching for 'Fully refundable' rates...
#
# Found 6 'Fully refundable' mentions
# ✓ Found fully refundable rate: $875.0
# ✓ Found fully refundable rate: $925.0
# ✓ Found fully refundable rate: $975.0
# ✓ Found fully refundable rate: $1125.0
# ✓ Found fully refundable rate: $1275.0
# ✓ Found fully refundable rate: $1425.0
#
# Unique fully refundable rates: [875.0, 925.0, 975.0, 1125.0, 1275.0, 1425.0]
# ✅ Lowest fully refundable rate: $875.0
# The Mercer - 2025-08-04 ✓ $875.0
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-The-Mercer.h118588.Hotel-Information?chk...
# Response status: 200
# ✓ Success! Page fetched.
# 🔍 Searching for 'Fully refundable' rates...
#
# Found 23 'Fully refundable' mentions
# ✓ Found fully refundable rate: $945.0
# ✓ Found fully refundable rate: $945.0
# ✓ Found fully refundable rate: $1020.0
# ✓ Found fully refundable rate: $1170.0
# ✓ Found fully refundable rate: $1405.0
# ✓ Found fully refundable rate: $1480.0
# ✓ Found fully refundable rate: $1550.0
# ✓ Found fully refundable rate: $1550.0
# ✓ Found fully refundable rate: $1550.0
# ✓ Found fully refundable rate: $1635.0
# ✓ Found fully refundable rate: $1635.0
# ✓ Found fully refundable rate: $1885.0
# ✓ Found fully refundable rate: $1885.0
# ✓ Found fully refundable rate: $2225.0
# ✓ Found fully refundable rate: $2225.0
# ✓ Found fully refundable rate: $2440.0
# ✓ Found fully refundable rate: $2440.0
# ✓ Found fully refundable rate: $2440.0
# ✓ Found fully refundable rate: $2440.0
# ✓ Found fully refundable rate: $3290.0
# ✓ Found fully refundable rate: $3290.0
# ✓ Found fully refundable rate: $12000.0
# ✓ Found fully refundable rate: $12000.0
#
# Unique fully refundable rates: [945.0, 1020.0, 1170.0, 1405.0, 1480.0, 1550.0, 1635.0, 1885.0, 2225.0, 2440.0, 3290.0, 12000.0]
# ✅ Lowest fully refundable rate: $945.0
# Pendry Manhattan West - 2025-08-06 ✓ $945.0
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-The-Mercer.h118588.Hotel-Information?chk...
# Progress: 40/180 (22%)
# Response status: 200
# ✓ Success! Page fetched.
# 🔍 Searching for 'Fully refundable' rates...
#
# Found 6 'Fully refundable' mentions
# ✓ Found fully refundable rate: $875.0
# ✓ Found fully refundable rate: $925.0
# ✓ Found fully refundable rate: $975.0
# ✓ Found fully refundable rate: $1125.0
# ✓ Found fully refundable rate: $1275.0
# ✓ Found fully refundable rate: $1425.0
#
# Unique fully refundable rates: [875.0, 925.0, 975.0, 1125.0, 1275.0, 1425.0]
# ✅ Lowest fully refundable rate: $875.0
# The Mercer - 2025-08-26 ✓ $875.0
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-Hotel-Barriere-Fouquets.h88270883.Hotel-...
# Response status: 200
# ✓ Success! Page fetched.
# 🔍 Searching for 'Fully refundable' rates...
#
# Found 6 'Fully refundable' mentions
# ✓ Found fully refundable rate: $875.0
# ✓ Found fully refundable rate: $925.0
# ✓ Found fully refundable rate: $975.0
# ✓ Found fully refundable rate: $1125.0
# ✓ Found fully refundable rate: $1275.0
# ✓ Found fully refundable rate: $1425.0
#
# Unique fully refundable rates: [875.0, 925.0, 975.0, 1125.0, 1275.0, 1425.0]
# ✅ Lowest fully refundable rate: $875.0
# The Mercer - 2025-08-16 ✓ $875.0
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-Hotel-Barriere-Fouquets.h88270883.Hotel-...
# Response status: 200
# ✓ Success! Page fetched.
# 🔍 Searching for 'Fully refundable' rates...
#
# Found 6 'Fully refundable' mentions
# ✓ Found fully refundable rate: $875.0
# ✓ Found fully refundable rate: $925.0
# ✓ Found fully refundable rate: $975.0
# ✓ Found fully refundable rate: $1125.0
# ✓ Found fully refundable rate: $1275.0
# ✓ Found fully refundable rate: $1425.0
#
# Unique fully refundable rates: [875.0, 925.0, 975.0, 1125.0, 1275.0, 1425.0]
# ✅ Lowest fully refundable rate: $875.0
# The Mercer - 2025-08-05 ✓ $875.0
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-Hotel-Barriere-Fouquets.h88270883.Hotel-...
# Response status: 200
# ✓ Success! Page fetched.
# 🔍 Searching for 'Fully refundable' rates...
#
# Found 6 'Fully refundable' mentions
# ✓ Found fully refundable rate: $875.0
# ✓ Found fully refundable rate: $925.0
# ✓ Found fully refundable rate: $975.0
# ✓ Found fully refundable rate: $1125.0
# ✓ Found fully refundable rate: $1275.0
# ✓ Found fully refundable rate: $1425.0
#
# Unique fully refundable rates: [875.0, 925.0, 975.0, 1125.0, 1275.0, 1425.0]
# ✅ Lowest fully refundable rate: $875.0
# The Mercer - 2025-08-27 ✓ $875.0
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-Hotel-Barriere-Fouquets.h88270883.Hotel-...
# Response status: 200
# ✓ Success! Page fetched.
# 🔍 Searching for 'Fully refundable' rates...
#
# Found 0 'Fully refundable' mentions
# ❌ No fully refundable rates found
# The Mercer - 2025-07-30 ✗ N/A
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-Hotel-Barriere-Fouquets.h88270883.Hotel-...
# Response status: 200
# ✓ Success! Page fetched.
# 🔍 Searching for 'Fully refundable' rates...
#
# Found 6 'Fully refundable' mentions
# ...
# ✓ Found fully refundable rate: $2705.0
# ✓ Found fully refundable rate: $3305.0
# ✓ Found fully refundable rate: $3605.0
# ✓ Found fully refundable rate: $5205.0
# ✓ Found fully refundable rate: $6555.0
#
# Unique fully refundable rates: [1225.0, 1265.0, 1285.0, 1385.0, 1805.0, 2005.0, 2305.0, 2555.0, 2705.0, 3305.0, 3605.0, 5205.0, 6555.0]
# ✅ Lowest fully refundable rate: $1225.0
# The Mark - 2025-08-26 ✓ $1225.0
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-Baccarat-Hotel-and-Residences.h9759603.H...
# Response status: 200
# ✓ Success! Page fetched.
# 🔍 Searching for 'Fully refundable' rates...
#
# Found 0 'Fully refundable' mentions
# ❌ No fully refundable rates found
# The Mark - 2025-08-13 ✗ N/A
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-Baccarat-Hotel-and-Residences.h9759603.H...
# Response status: 520
# ✗ Error: Status code 520
# Response: Request failed, with status codes original_status: 504 and pc_status: 530. Please try the request again, as this one is not charged, or contact support if the problem persists. If you want close to 10
# The Mark - 2025-08-07 ✗ N/A
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-Baccarat-Hotel-and-Residences.h9759603.H...
# Response status: 200
# ✓ Success! Page fetched.
# 🔍 Searching for 'Fully refundable' rates...
#
# Found 2 'Fully refundable' mentions
# ✓ Found fully refundable rate: $1563.0
# ✓ Found fully refundable rate: $2019.0
#
# Unique fully refundable rates: [1563.0, 2019.0]
# ✅ Lowest fully refundable rate: $1563.0
# Baccarat Hotel and Residences - 2025-08-05 ✓ $1563.0
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-Baccarat-Hotel-and-Residences.h9759603.H...
# Response status: 200
# ✓ Success! Page fetched.
# 🔍 Searching for 'Fully refundable' rates...
#
# Found 5 'Fully refundable' mentions
# ✓ Found fully refundable rate: $1135.0
# ✓ Found fully refundable rate: $1539.0
# ✓ Found fully refundable rate: $1648.0
# ✓ Found fully refundable rate: $1990.0
# ✓ Found fully refundable rate: $1990.0
#
# Unique fully refundable rates: [1135.0, 1539.0, 1648.0, 1990.0]
# ✅ Lowest fully refundable rate: $1135.0
# Baccarat Hotel and Residences - 2025-08-04 ✓ $1135.0
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-Baccarat-Hotel-and-Residences.h9759603.H...
# Response status: 200
# ✓ Success! Page fetched.
# 🔍 Searching for 'Fully refundable' rates...
#
# Found 6 'Fully refundable' mentions
# ✓ Found fully refundable rate: $1031.0
# ✓ Found fully refundable rate: $1069.0
# ✓ Found fully refundable rate: $1292.0
# ✓ Found fully refundable rate: $1449.0
# ✓ Found fully refundable rate: $1696.0
# ✓ Found fully refundable rate: $1981.0
#
# Unique fully refundable rates: [1031.0, 1069.0, 1292.0, 1449.0, 1696.0, 1981.0]
# ✅ Lowest fully refundable rate: $1031.0
# Baccarat Hotel and Residences - 2025-08-11 ✓ $1031.0
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-Baccarat-Hotel-and-Residences.h9759603.H...
# Response status: 200
# ✓ Success! Page fetched.
# 🔍 Searching for 'Fully refundable' rates...
#
# Found 6 'Fully refundable' mentions
# ✓ Found fully refundable rate: $1040.0
# ✓ Found fully refundable rate: $1069.0
# ✓ Found fully refundable rate: $1302.0
# ✓ Found fully refundable rate: $1506.0
# ✓ Found fully refundable rate: $1705.0
# ✓ Found fully refundable rate: $1895.0
#
# Unique fully refundable rates: [1040.0, 1069.0, 1302.0, 1506.0, 1705.0, 1895.0]
# ✅ Lowest fully refundable rate: $1040.0
# Baccarat Hotel and Residences - 2025-08-08 ✓ $1040.0
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-Baccarat-Hotel-and-Residences.h9759603.H...
# Progress: 150/180 (83%)
# Response status: 200
# ✓ Success! Page fetched.
# 🔍 Searching for 'Fully refundable' rates...
#
# Found 6 'Fully refundable' mentions
# ✓ Found fully refundable rate: $1135.0
# ✓ Found fully refundable rate: $1164.0
# ✓ Found fully refundable rate: $1373.0
# ✓ Found fully refundable rate: $1563.0
# ✓ Found fully refundable rate: $1705.0
# ✓ Found fully refundable rate: $1990.0
#
# Unique fully refundable rates: [1135.0, 1164.0, 1373.0, 1563.0, 1705.0, 1990.0]
# ✅ Lowest fully refundable rate: $1135.0
# Baccarat Hotel and Residences - 2025-08-09 ✓ $1135.0
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-Baccarat-Hotel-and-Residences.h9759603.H...
# Response status: 520
# ✗ Error: Status code 520
# Response: <html><head><title>Bot or Not?</title><meta charset="UTF-8"><meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"><meta name="viewport" content="width=device-width, initial-scale=1.0"><meta na
# Baccarat Hotel and Residences - 2025-08-01 ✗ N/A
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-Baccarat-Hotel-and-Residences.h9759603.H...
# Response status: 520
# ✗ Error: Status code 520
# Response: Request failed, with status codes original_status: 504 and pc_status: 0. Please try the request again, as this one is not charged, or contact support if the problem persists. If you want close to 100%
# The Mark - 2025-08-15 ✗ N/A
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-Baccarat-Hotel-and-Residences.h9759603.H...
# Response status: 200
# ✓ Success! Page fetched.
# 🔍 Searching for 'Fully refundable' rates...
#
# Found 6 'Fully refundable' mentions
# ✓ Found fully refundable rate: $993.0
# ✓ Found fully refundable rate: $1021.0
# ✓ Found fully refundable rate: $1230.0
# ✓ Found fully refundable rate: $1468.0
# ✓ Found fully refundable rate: $1563.0
# ✓ Found fully refundable rate: $1753.0
#
# Unique fully refundable rates: [993.0, 1021.0, 1230.0, 1468.0, 1563.0, 1753.0]
# ✅ Lowest fully refundable rate: $993.0
# Baccarat Hotel and Residences - 2025-08-10 ✓ $993.0
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-Baccarat-Hotel-and-Residences.h9759603.H...
# Response status: 200
# ✓ Success! Page fetched.
# 🔍 Searching for 'Fully refundable' rates...
#
# Found 5 'Fully refundable' mentions
# ✓ Found fully refundable rate: $1088.0
# ✓ Found fully refundable rate: $1302.0
# ✓ Found fully refundable rate: $1601.0
# ✓ Found fully refundable rate: $1753.0
# ✓ Found fully refundable rate: $2038.0
#
# Unique fully refundable rates: [1088.0, 1302.0, 1601.0, 1753.0, 2038.0]
# ✅ Lowest fully refundable rate: $1088.0
# Baccarat Hotel and Residences - 2025-08-19 ✓ $1088.0
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-Baccarat-Hotel-and-Residences.h9759603.H...
# Response status: 200
# ✓ Success! Page fetched.
# 🔍 Searching for 'Fully refundable' rates...
#
# Found 3 'Fully refundable' mentions
# ✓ Found fully refundable rate: $1245.0
# ✓ Found fully refundable rate: $1275.0
# ✓ Found fully refundable rate: $1770.0
#
# Unique fully refundable rates: [1245.0, 1275.0, 1770.0]
# ✅ Lowest fully refundable rate: $1245.0
# Baccarat Hotel and Residences - 2025-07-31 ✓ $1245.0
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-Baccarat-Hotel-and-Residences.h9759603.H...
# Response status: 200
# ✓ Success! Page fetched.
# 🔍 Searching for 'Fully refundable' rates...
#
# Found 11 'Fully refundable' mentions
# ✓ Found fully refundable rate: $1045.0
# ✓ Found fully refundable rate: $1085.0
# ✓ Found fully refundable rate: $1105.0
# ✓ Found fully refundable rate: $1205.0
# ✓ Found fully refundable rate: $1625.0
# ✓ Found fully refundable rate: $1825.0
# ✓ Found fully refundable rate: $2125.0
# ✓ Found fully refundable rate: $2375.0
# ✓ Found fully refundable rate: $2525.0
# ✓ Found fully refundable rate: $3325.0
# ✓ Found fully refundable rate: $3425.0
#
# Unique fully refundable rates: [1045.0, 1085.0, 1105.0, 1205.0, 1625.0, 1825.0, 2125.0, 2375.0, 2525.0, 3325.0, 3425.0]
# ✅ Lowest fully refundable rate: $1045.0
# The Mark - 2025-08-16 ✓ $1045.0
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-Baccarat-Hotel-and-Residences.h9759603.H...
# Response status: 520
# ✗ Error: Status code 520
# Response: <html><head><title>Bot or Not?</title><meta charset="UTF-8"><meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"><meta name="viewport" content="width=device-width, initial-scale=1.0"><meta na
# Baccarat Hotel and Residences - 2025-08-03 ✗ N/A
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-Baccarat-Hotel-and-Residences.h9759603.H...
# Response status: 200
# ✓ Success! Page fetched.
# 🔍 Searching for 'Fully refundable' rates...
#
# Found 0 'Fully refundable' mentions
# ❌ No fully refundable rates found
# Baccarat Hotel and Residences - 2025-08-23 ✗ N/A
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-Baccarat-Hotel-and-Residences.h9759603.H...
# Response status: 200
# ✓ Success! Page fetched.
# 🔍 Searching for 'Fully refundable' rates...
#
# Found 0 'Fully refundable' mentions
# ❌ No fully refundable rates found
# Baccarat Hotel and Residences - 2025-08-24 ✗ N/A
# Fetching URL via Crawlbase...
# Target URL: https://www.expedia.com/New-York-Hotels-Baccarat-Hotel-and-Residences.h9759603.H...
# Progress: 160/180 (89%)
# Response status: 520
# ✗ Error: Status code 520
# Response: Request failed, with status codes original_status: 504 and pc_status: 599. Please try the request again, as this one is not charged, or contact support if the problem persists. If you want close to 10
# The Mark - 2025-08-24 ✗ N/A
# Response status: 200
# ✓ Success! Page fetched.
# 🔍 Searching for 'Fully refundable' rates...
#
# Found 0 'Fully refundable' mentions
# ❌ No fully refundable rates found
# The Mark - 2025-08-23 ✗ N/A
# Response status: 200
# ✓ Success! Page fetched.
# 🔍 Searching for 'Fully refundable' rates...
#
# Found 6 'Fully refundable' mentions
# ✓ Found fully refundable rate: $974.0
# ✓ Found fully refundable rate: $988.0
# ✓ Found fully refundable rate: $1188.0
# ✓ Found fully refundable rate: $1392.0
# ✓ Found fully refundable rate: $1639.0
# ✓ Found fully refundable rate: $1829.0
#
# Unique fully refundable rates: [974.0, 988.0, 1188.0, 1392.0, 1639.0, 1829.0]
# ✅ Lowest fully refundable rate: $974.0
# Baccarat Hotel and Residences - 2025-08-17 ✓ $974.0
# Response status: 200
# ✓ Success! Page fetched.
# Response status: 200
# ✓ Success! Page fetched.
# 🔍 Searching for 'Fully refundable' rates...
#
# Found 5 'Fully refundable' mentions
# ✓ Found fully refundable rate: $1135.0
# ✓ Found fully refundable rate: $1397.0
# ✓ Found fully refundable rate: $1648.0
# ✓ Found fully refundable rate: $1800.0
# ✓ Found fully refundable rate: $2085.0
#
# Unique fully refundable rates: [1135.0, 1397.0, 1648.0, 1800.0, 2085.0]
# ✅ Lowest fully refundable rate: $1135.0
# Baccarat Hotel and Residences - 2025-08-20 ✓ $1135.0
# 🔍 Searching for 'Fully refundable' rates...
#
# Found 3 'Fully refundable' mentions
# ✓ Found fully refundable rate: $1249.0
# ✓ Found fully refundable rate: $1705.0
# ✓ Found fully refundable rate: $1895.0
#
# Unique fully refundable rates: [1249.0, 1705.0, 1895.0]
# ✅ Lowest fully refundable rate: $1249.0
# Baccarat Hotel and Residences - 2025-08-06 ✓ $1249.0
# Response status: 200
# ✓ Success! Page fetched.
# 🔍 Searching for 'Fully refundable' rates...
#
# Found 5 'Fully refundable' mentions
# ✓ Found fully refundable rate: $1420.0
# ✓ Found fully refundable rate: $1458.0
# ✓ Found fully refundable rate: $1682.0
# ✓ Found fully refundable rate: $2085.0
# ✓ Found fully refundable rate: $2275.0
#
# Unique fully refundable rates: [1420.0, 1458.0, 1682.0, 2085.0, 2275.0]
# ✅ Lowest fully refundable rate: $1420.0
# Baccarat Hotel and Residences - 2025-08-26 ✓ $1420.0
# Response status: 504
# ✗ Error: Status code 504
# Response: Request failed, with status codes original_status: 504 and pc_status: 504. Please try the request again, as this one is not charged, or contact support if the problem persists. If you want close to 10
# The Mark - 2025-08-20 ✗ N/A
# Response status: 520
# ✗ Error: Status code 520
# Response: <html><head><title>Bot or Not?</title><meta charset="UTF-8"><meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"><meta name="viewport" content="width=device-width, initial-scale=1.0"><meta na
# Baccarat Hotel and Residences - 2025-08-13 ✗ N/A
# Response status: 520
# ✗ Error: Status code 520
# Response: Request failed, with status codes original_status: 504 and pc_status: 530. Please try the request again, as this one is not charged, or contact support if the problem persists. If you want close to 10
# Baccarat Hotel and Residences - 2025-08-07 ✗ N/A
# Response status: 200
# ✓ Success! Page fetched.
# 🔍 Searching for 'Fully refundable' rates...
#
# Found 6 'Fully refundable' mentions
# ✓ Found fully refundable rate: $1069.0
# ✓ Found fully refundable rate: $1083.0
# ✓ Found fully refundable rate: $1283.0
# ✓ Found fully refundable rate: $1534.0
# ✓ Found fully refundable rate: $1734.0
# ✓ Found fully refundable rate: $1924.0
#
# Unique fully refundable rates: [1069.0, 1083.0, 1283.0, 1534.0, 1734.0, 1924.0]
# ✅ Lowest fully refundable rate: $1069.0
# Baccarat Hotel and Residences - 2025-08-25 ✓ $1069.0
# Progress: 170/180 (94%)
# Response status: 520
# ✗ Error: Status code 520
# Response: <html><head><title>Bot or Not?</title><meta charset="UTF-8"><meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"><meta name="viewport" content="width=device-width, initial-scale=1.0"><meta na
# Baccarat Hotel and Residences - 2025-07-30 ✗ N/A
# Response status: 520
# ✗ Error: Status code 520
# Response: <html><head><title>Bot or Not?</title><meta charset="UTF-8"><meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"><meta name="viewport" content="width=device-width, initial-scale=1.0"><meta na
# Baccarat Hotel and Residences - 2025-08-14 ✗ N/A
# Response status: 520
# ✗ Error: Status code 520
# Response: <html><head><title>Bot or Not?</title><meta charset="UTF-8"><meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"><meta name="viewport" content="width=device-width, initial-scale=1.0"><meta na
# Baccarat Hotel and Residences - 2025-08-27 ✗ N/A
# Response status: 520
# ✗ Error: Status code 520
# Response: Request failed, with status codes original_status: 504 and pc_status: 594. Please try the request again, as this one is not charged, or contact support if the problem persists. If you want close to 10
# Baccarat Hotel and Residences - 2025-08-12 ✗ N/A
# Response status: 520
# ✗ Error: Status code 520
# Response: <html><head>
# <title>Access Denied</title>
# </head><body>
# <h1>Access Denied</h1>
#
# You don't have permission to access "http://www.expedia.com/New-York-Hotels-Baccarat-Hotel-and-Residences.h9759603.Hote
# Baccarat Hotel and Residences - 2025-08-15 ✗ N/A
# Response status: 520
# ✗ Error: Status code 520
# Response: <html><head><title>Bot or Not?</title><meta charset="UTF-8"><meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"><meta name="viewport" content="width=device-width, initial-scale=1.0"><meta na
# Baccarat Hotel and Residences - 2025-08-28 ✗ N/A
# Response status: 520
# ✗ Error: Status code 520
# Response: <html><head><title>Bot or Not?</title><meta charset="UTF-8"><meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"><meta name="viewport" content="width=device-width, initial-scale=1.0"><meta na
# Baccarat Hotel and Residences - 2025-08-16 ✗ N/A
# Response status: 520
# ✗ Error: Status code 520
# Response: Request failed, with status codes original_status: 504 and pc_status: 0. Please try the request again, as this one is not charged, or contact support if the problem persists. If you want close to 100%
# Baccarat Hotel and Residences - 2025-08-18 ✗ N/A
# Response status: 520
# ✗ Error: Status code 520
# Response: <html><head><title>Bot or Not?</title><meta charset="UTF-8"><meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"><meta name="viewport" content="width=device-width, initial-scale=1.0"><meta na
# Baccarat Hotel and Residences - 2025-08-22 ✗ N/A
# Response status: 520
# ✗ Error: Status code 520
# Response: <html><head>
# <title>Access Denied</title>
# </head><body>
# <h1>Access Denied</h1>
#
# You don't have permission to access "http://www.expedia.com/New-York-Hotels-Baccarat-Hotel-and-Residences.h9759603.Hote
# Baccarat Hotel and Residences - 2025-08-21 ✗ N/A
# Progress: 180/180 (100%)
#
# ==================================================
# ✅ Scraping complete! 180 results collected.

# %%
# Cell 12: Save Results to CSV and Upload to Azure
from azure.storage.blob import BlobServiceClient

def save_results_to_csv(results, filename=None):
    """
    Save scraping results to CSV file and upload to Azure
    """
    
    if not results:
        print("❌ No results to save")
        return
    
    # Convert to DataFrame
    df = pd.DataFrame(results)
    
    # Generate filename if not provided
    if filename is None:
        timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
        filename = f'HIP_rates_{timestamp}.csv'
    
    # Save to CSV locally
    df.to_csv(filename, index=False)
    print(f"✅ Saved {len(df)} rows to {filename}")
    
    # Also save as .txt to avoid Excel auto-conversion
    txt_filename = filename.replace('.csv', '.txt')
    df.to_csv(txt_filename, index=False)
    print(f"✅ Also saved as {txt_filename}")
    
    # Upload to Azure
    try:
        with open('azure_config.txt', 'r') as f:
            connection_string = f.read().strip()
            
        blob_service_client = BlobServiceClient.from_connection_string(connection_string)
        container_name = "hip-hotel-rates"
        
        # Upload CSV to Azure
        csv_data = df.to_csv(index=False)
        blob_client = blob_service_client.get_blob_client(
            container=container_name, 
            blob=f"rates/{filename}"
        )
        blob_client.upload_blob(csv_data, overwrite=True)
        print(f"☁️  Uploaded to Azure: {container_name}/rates/{filename}")
        
    except Exception as e:
        print(f"⚠️  Azure upload failed (data saved locally): {e}")
    
    # Show summary statistics
    print("\n📊 Summary Statistics:")
    print(f"Total hotels: {df['hotel_name'].nunique()}")
    print(f"Date range: {df['check_in_date'].min()} to {df['check_in_date'].max()}")
    print(f"Available rates: {df['is_available'].sum()} out of {len(df)}")
    
    if df['price'].notna().any():
        print(f"\n💰 Price Statistics:")
        print(f"Average price: ${df['price'].mean():.2f}")
        print(f"Lowest price: ${df['price'].min():.2f}")
        print(f"Highest price: ${df['price'].max():.2f}")
    
    return df.head(10)

# Save our test results
if results:
    df_results = save_results_to_csv(results)
    display(df_results)
# Out:
# ✅ Saved 180 rows to HIP_rates_20250730_110708.csv
# ✅ Also saved as HIP_rates_20250730_110708.txt
# ☁️  Uploaded to Azure: hip-hotel-rates/rates/HIP_rates_20250730_110708.csv
#
# 📊 Summary Statistics:
# Total hotels: 6
# Date range: 2025-07-30 to 2025-08-28
# Available rates: 112 out of 180
#
# 💰 Price Statistics:
# Average price: $1004.17
# Lowest price: $650.00
# Highest price: $1563.00
#               hotel_name  hotel_id check_in_date check_out_date  price  \
# 0  Pendry Manhattan West  68272643    2025-08-03     2025-08-04  870.0
# 1  Pendry Manhattan West  68272643    2025-08-05     2025-08-06  945.0
# 2  Pendry Manhattan West  68272643    2025-07-30     2025-07-31    NaN
# 3  Pendry Manhattan West  68272643    2025-08-02     2025-08-03  795.0
# 4  Pendry Manhattan West  68272643    2025-08-15     2025-08-16  675.0
# 5  Pendry Manhattan West  68272643    2025-08-08     2025-08-09  795.0
# 6  Pendry Manhattan West  68272643    2025-08-11     2025-08-12  900.0
# 7  Pendry Manhattan West  68272643    2025-08-13     2025-08-14  840.0
# 8  Pendry Manhattan West  68272643    2025-08-21     2025-08-22  760.0
# 9  Pendry Manhattan West  68272643    2025-08-01     2025-08-02  795.0
#
#    is_available     scrape_timestamp scrape_date
# 0          True  2025-07-30 10:56:12  2025-07-30
# 1          True  2025-07-30 10:56:13  2025-07-30
# 2         False  2025-07-30 10:56:14  2025-07-30
# 3          True  2025-07-30 10:56:16  2025-07-30
# 4          True  2025-07-30 10:56:17  2025-07-30
# 5          True  2025-07-30 10:56:18  2025-07-30
# 6          True  2025-07-30 10:56:20  2025-07-30
# 7          True  2025-07-30 10:56:25  2025-07-30
# 8          True  2025-07-30 10:56:27  2025-07-30
# 9          True  2025-07-30 10:56:29  2025-07-30

# %%
# Cell 13: Analyze Results (Enhanced)
# Let's visualize what we collected
if 'results' in globals() and results and len(results) > 0:
    df = pd.DataFrame(results)
    
    print(f"📊 Analysis of {len(df)} scraping results\n")
    
    # Show availability summary
    available_count = df['is_available'].sum()
    print(f"Available rates: {available_count} out of {len(df)} ({available_count/len(df)*100:.1f}%)")
    
    # Create a pivot table to see prices by hotel and date
    if df['price'].notna().any():
        # Ensure we have only one price per hotel/date (the lowest)
        df_clean = df.groupby(['hotel_name', 'check_in_date']).agg({
            'price': 'min',
            'is_available': 'first'
        }).reset_index()
        
        pivot = df_clean.pivot_table(
            values='price', 
            index='hotel_name', 
            columns='check_in_date', 
            aggfunc='first'
        )
        
        print("\n💰 Price Matrix (Hotel x Date):")
        display(pivot)
        
        # Quick visualization
        import matplotlib.pyplot as plt
        
        # Plot prices over time for each hotel
        plt.figure(figsize=(12, 8))
        
        for hotel in df_clean['hotel_name'].unique():
            hotel_data = df_clean[df_clean['hotel_name'] == hotel]
            available_data = hotel_data[hotel_data['price'].notna()]
            
            if not available_data.empty:
                # Sort by date for smooth line
                available_data = available_data.sort_values('check_in_date')
                
                plt.plot(
                    pd.to_datetime(available_data['check_in_date']), 
                    available_data['price'], 
                    marker='o', 
                    label=hotel,
                    linewidth=2,
                    markersize=6
                )
        
        plt.xlabel('Check-in Date')
        plt.ylabel('Price ($)')
        plt.title('Hotel Rates Over Time (Lowest Fully Refundable Rate per Day)')
        plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
        plt.grid(True, alpha=0.3)
        plt.xticks(rotation=45)
        
        # Set y-axis to start at 0 for better comparison
        plt.ylim(bottom=0)
        
        plt.tight_layout()
        plt.show()
    else:
        print("\n❌ No price data available to visualize")
        print("This is expected if all dates are within 72-hour booking window")
        
        # Show availability by date
        availability_by_date = df.groupby('check_in_date')['is_available'].sum()
        print(f"\nAvailability by date:")
        print(availability_by_date)
else:
    print("❌ No results found. Please run the scraping cells first.")
# Out:
# 📊 Analysis of 180 scraping results
#
# Available rates: 112 out of 180 (62.2%)
#
# 💰 Price Matrix (Hotel x Date):
# check_in_date                  2025-07-31  2025-08-01  2025-08-02  2025-08-03  \
# hotel_name
# Baccarat Hotel and Residences      1245.0         NaN      1164.0         NaN
# Casa Cipriani                         NaN         NaN         NaN         NaN
# Hotel Barriere Fouquets               NaN      1100.0         NaN      1100.0
# Pendry Manhattan West                 NaN       795.0       795.0       870.0
# The Mark                              NaN      1075.0      1075.0      1045.0
# The Mercer                            NaN         NaN       875.0       875.0
#
# check_in_date                  2025-08-04  2025-08-05  2025-08-06  2025-08-07  \
# hotel_name
# Baccarat Hotel and Residences      1135.0      1563.0      1249.0         NaN
# Casa Cipriani                      1300.0         NaN         NaN      1300.0
# Hotel Barriere Fouquets               NaN      1100.0         NaN         NaN
# Pendry Manhattan West                 NaN       945.0       945.0       795.0
# The Mark                           1045.0      1195.0      1195.0         NaN
# The Mercer                          875.0       875.0       875.0       875.0
#
# check_in_date                  2025-08-08  2025-08-09  ...  2025-08-19  \
# hotel_name                                             ...
# Baccarat Hotel and Residences      1040.0      1135.0  ...      1088.0
# Casa Cipriani                         NaN         NaN  ...       980.0
# Hotel Barriere Fouquets            1250.0      1248.0  ...      1100.0
# Pendry Manhattan West               795.0       795.0  ...       780.0
# The Mark                           1095.0         NaN  ...      1095.0
# The Mercer                          875.0       875.0  ...      1125.0
#
# check_in_date                  2025-08-20  2025-08-21  2025-08-22  2025-08-23  \
# hotel_name
# Baccarat Hotel and Residences      1135.0         NaN         NaN         NaN
# Casa Cipriani                         NaN         NaN       980.0         NaN
# Hotel Barriere Fouquets            1100.0      1100.0      1100.0      1100.0
# Pendry Manhattan West               810.0       760.0       650.0       650.0
# The Mark                              NaN      1045.0      1095.0         NaN
# The Mercer                         1275.0       925.0       875.0         NaN
#
# check_in_date                  2025-08-24  2025-08-25  2025-08-26  2025-08-27  \
# hotel_name
# Baccarat Hotel and Residences         NaN      1069.0      1420.0         NaN
# Casa Cipriani                       980.0       980.0         NaN         NaN
# Hotel Barriere Fouquets            1100.0         NaN      1250.0         NaN
# Pendry Manhattan West               700.0       760.0       960.0       995.0
# The Mark                              NaN         NaN      1225.0      1225.0
# The Mercer                          875.0       875.0       875.0       875.0
#
# check_in_date                  2025-08-28
# hotel_name
# Baccarat Hotel and Residences         NaN
# Casa Cipriani                         NaN
# Hotel Barriere Fouquets            1100.0
# Pendry Manhattan West               895.0
# The Mark                           1155.0
# The Mercer                          875.0
#
# [6 rows x 29 columns]
